# %%
# Please do not change this cell because some hidden tests might depend on it.
import os

# Otter grader does not handle ! commands well, so we define and use our
# own function to execute shell commands.
def shell(commands, warn=True):
    """Executes the string `commands` as a sequence of shell commands.
     
       Prints the result to stdout and returns the exit status. 
       Provides a printed warning on non-zero exit status unless `warn` 
       flag is unset.
    """
    file = os.popen(commands)
    print (file.read().rstrip('\n'))
    exit_status = file.close()
    if warn and exit_status != None:
        print(f"Completed with errors. Exit status: {exit_status}\n")
    return exit_status

shell("""
ls requirements.txt >/dev/null 2>&1
if [ ! $? = 0 ]; then
 rm -rf .tmp
 git clone https://github.com/cs236299-2022-spring/project3.git .tmp
 mv .tmp/requirements.txt ./
 rm -rf .tmp
fi
pip install -q -r requirements.txt
""")

# %%
# Initialize Otter
import otter
grader = otter.Notebook()

# %% [raw]
# %%latex
# \newcommand{\vect}[1]{\mathbf{#1}}
# \newcommand{\cnt}[1]{\sharp(#1)}
# \newcommand{\argmax}[1]{\underset{#1}{\operatorname{argmax}}}
# \newcommand{\softmax}{\operatorname{softmax}}
# \newcommand{\Prob}{\Pr}
# \newcommand{\given}{\,|\,}

# %% [markdown]
# $$
# \renewcommand{\vect}[1]{\mathbf{#1}}
# \renewcommand{\cnt}[1]{\sharp(#1)}
# \renewcommand{\argmax}[1]{\underset{#1}{\operatorname{argmax}}}
# \renewcommand{\softmax}{\operatorname{softmax}}
# \renewcommand{\Prob}{\Pr}
# \renewcommand{\given}{\,|\,}
# $$

# %% [markdown]
# # 	236299 - Introduction to Natural Language Processing
# ## Project 3: Parsing – The CKY Algorithm

# %% [markdown]
# Constituency parsing is the recovery of a labeled hierarchical structure, a _parse tree_ for a sentence of a natural language. It is a core intermediary task in natural-language processing, as the meanings of sentences are related to their structure.
#
# In this project, you will implement the CKY algorithm for parsing strings relative to context-free grammars (CFG). You will implement versions for both non-probabilistic context-free grammars (CFG) and probabilistic grammars (PCFG) and apply them to the parsing of ATIS queries.
#
# The project is structured into five parts:
#
# 1. Finish a CFG for the ATIS dataset.
# 2. Implement the CKY algorithm for _recognizing_ grammatical sentences, that is, determining whether a parse exists for a given sentence.
# 3. Extend the CKY algorithm for _parsing_ sentences, that is, constructing the parse trees for a given sentence.
# 4. Construct a probabilistic context-free grammar (PCFG) based on a CFG.
# 5. Extend the CKY algorithm to PCFGs, allowing the construction of the most probable parse tree for a sentence according to a PCFG.
#
# # Setup

# %%
# Download needed files and scripts
import wget
os.makedirs('data', exist_ok=True)
os.makedirs('scripts', exist_ok=True)
# ATIS queries
wget.download("https://raw.githubusercontent.com/nlp-236299/data/master/ATIS/train.nl", out="data/")
# Corresponding parse trees
wget.download("https://raw.githubusercontent.com/nlp-236299/data/master/ATIS/train.trees", out="data/")
wget.download("https://raw.githubusercontent.com/nlp-236299/data/master/ATIS/test.trees", out="data/")

# Code for comparing and evaluating parse trees
wget.download("https://raw.githubusercontent.com/nlp-236299/data/master/scripts/trees/evalb.py", out="scripts/")
wget.download("https://raw.githubusercontent.com/nlp-236299/data/master/scripts/trees/transform.py", out="scripts/")
wget.download("https://raw.githubusercontent.com/nlp-236299/data/master/scripts/trees/tree.py", out="scripts/")
# Out:
# 100% [................................................................................] 7773 / 7773
# 'scripts//tree (1).py'

# %%
import shutil

import nltk

import sys

from collections import defaultdict, Counter

from nltk import treetransforms
from nltk.grammar import ProbabilisticProduction, PCFG, Nonterminal
from nltk.tree import Tree

from tqdm import tqdm

# Import functions for transforming augmented grammars
sys.path.insert(1, './scripts')
import transform as xform

# %%
## Debug flag used below for turning on and off some useful tracing
DEBUG = False

# %% [markdown]
# # A custom ATIS grammar

# %% [markdown]
# To parse, we need a grammar. In this project, you will use a hand-crafted grammar for a fragment of the ATIS dataset. The grammar is written in a "semantic grammar" style, in which the nonterminals tend to correspond to semantic classes of phrases, rather than syntactic classes. By using this style, we can more closely tune the grammar to the application, though we lose generality and transferability to other applications. The grammar will be used again in the next project segment for a question-answering application.
#
# We download the grammar to make it available.

# %%
if not os.path.exists('./data/grammar_distrib3'):
  wget.download("https://raw.githubusercontent.com/nlp-236299/data/master/ATIS/grammar_distrib3", out="data/")
if os.path.exists('./data/grammar_distrib3') and (not os.path.exists('./data/grammar')):
  shutil.copy('./data/grammar_distrib3', './data/grammar')

# %% [markdown]
# Take a look at the file `data/grammar_distrib3` that you've just downloaded. The grammar is written in a format that extends the NLTK format expected by `CFG.fromstring`. We've provided functions to make use of this format in the file `scripts/transform.py`. You should familiarize yourself with this format by checking out the documentation in that file.
#
# > We made a copy of this grammar for you as `data/grammar`. This is the file you'll be modifying in the next section. You can leave it alone for now.
#
# As described there, we can read the grammar in and convert it into NLTK's grammar format using the provided `xform.read_augmented_grammar` function.

# %%
atis_grammar_distrib, _ = xform.read_augmented_grammar("grammar_distrib3", path="data")

# %% [markdown]
# To verify that the ATIS grammar that we distributed is working, we can parse a sentence using a built-in NLTK parser. We'll use a tokenizer built with NLTK's tokenizing apparatus.

# %%
## Tokenizer
tokenizer = nltk.tokenize.RegexpTokenizer('\d+|[\w-]+|\$[\d\.]+|\S+')
def tokenize(string):
  return tokenizer.tokenize(string.lower())

## Demonstrating the tokenizer
## Note especially the handling of `"11pm"` and hyphenated words.
print(tokenize("Are there any first-class flights at 11pm for less than $3.50?"))
# Out:
# ['are', 'there', 'any', 'first-class', 'flights', 'at', '11', 'pm', 'for', 'less', 'than', '$3.50', '?']

# %%
## Test sentence
test_sentence_1 = tokenize("show me the flights before noon")

## Construct parser from distribution grammar
atis_parser_distrib = nltk.parse.BottomUpChartParser(atis_grammar_distrib)

## Parse and print the parses
parses = atis_parser_distrib.parse(test_sentence_1)
for parse in parses:
  parse.pretty_print()
# Out:
#                                                  S
#                         _________________________|________________________
#                        |                                              NP_FLIGHT
#                        |                                                  |
#                        |                                              NOM_FLIGHT
#                        |                                                  |
#                        |                                               N_FLIGHT
#                        |                                        __________|_________
#                    PREIGNORE                                   |                    PP
#         _______________|____________                           |                    |
#        |                        PREIGNORE                      |                 PP_TIME
#        |                ____________|____________              |           _________|________
#        |               |                     PREIGNORE      N_FLIGHT      |               NP_TIME
#        |               |                         |             |          |                  |
# PREIGNORESYMBOL PREIGNORESYMBOL           PREIGNORESYMBOL TERM_FLIGHT   P_TIME           TERM_TIME
#        |               |                         |             |          |                  |
#       show             me                       the         flights     before              noon
#
#                                            S
#                      ______________________|__________________
#                     |                                     NP_FLIGHT
#                     |                       __________________|_________
#                     |                      |                        NOM_FLIGHT
#                     |                      |                            |
#                     |                      |                         N_FLIGHT
#                     |                      |        ____________________|_________
#                     |                      |       |                              PP
#                     |                      |       |                              |
#                 PREIGNORE                  |       |                           PP_TIME
#         ____________|____________          |       |                     _________|________
#        |                     PREIGNORE     |    N_FLIGHT                |               NP_TIME
#        |                         |         |       |                    |                  |
# PREIGNORESYMBOL           PREIGNORESYMBOL DET TERM_FLIGHT             P_TIME           TERM_TIME
#        |                         |         |       |                    |                  |
#       show                       me       the   flights               before              noon

# %% [markdown]
# ## Testing the coverage of the grammar
#
# We can get a sense of how well the grammar covers the ATIS query language by measuring the proportion of queries in the training set that are parsable by the grammar. We define a `coverage` function to carry out this evaluation.
#
# > Warning: It may take a long time to parse all of the sentence in the training corpus, on the order of 30 minutes. You may want to start with just the first few sentences in the corpus. The `coverage` function below makes it easy to do so, and in the code below we just test coverage on the first 50 sentences.

# %%
## Read in the training corpus
with open('data/train.nl') as file:
  training_corpus = [tokenize(line) for line in file]

# %%
def coverage(recognizer, corpus, n=0):
  """Returns the proportion of the first `n` sentences in the `corpus` 
  that are recognized by the `recognizer`, which should return a boolean.
  `n` is taken to be the whole corpus if n is not provided or is
  non-positive.
  """
  n = len(corpus) if n <= 0 else n
  parsed = 0
  total = 0
  for sent in tqdm(corpus[:n]):
    total += 1
    try:
      parses = recognizer(sent)
    except:
      print(sent)
      parses = None
    if parses:
      parsed += 1
    elif DEBUG:
      print(f"failed: {sent}")
  if DEBUG: print(f"{parsed} of {total}")
  return parsed/total

# %%
coverage(lambda sent: 0 < len(list(atis_parser_distrib.parse(sent))),  # trick for turning parser into recognizer
         training_corpus, n=50)
# Out:
#  54%|███████████████████████████████████████████▋                                     | 27/50 [00:00<00:00, 127.34it/s]
# ['i', "'d", 'like', 'to', 'see', 'flights', 'from', 'baltimore', 'to', 'atlanta', 'that', 'arrive', 'before', 'noon', 'and', 'i', "'d", 'like', 'to', 'see', 'flights', 'from', 'denver', 'to', 'atlanta', 'that', 'arrive', 'before', 'noon']
# ['do', 'you', 'have', 'an', '819', 'flight', 'from', 'denver', 'to', 'san', 'francisco']
# ['how', 'can', 'i', 'get', 'from', 'boston', 'to', 'atlanta', 'and', 'back', 'in', 'the', 'same', 'day', 'and', 'have', 'the', 'most', 'hours', 'on', 'the', 'ground', 'in', 'atlanta']
# ['are', 'there', 'any', 'flights', 'between', 'pittsburgh', 'and', 'baltimore', 'using', 'a', 'j31', 'aircraft']
# ['what', 'does', 'd', '/s', 'stand', 'for', 'for', 'meals']
# ['i', 'need', 'the', 'cost', 'of', 'a', 'ticket', 'going', 'from', 'denver', 'to', 'baltimore', 'a', 'first', 'class', 'ticket', 'on', 'united', 'airlines']
# ['is', 'there', 'a', 'flight', 'between', 'san', 'francisco', 'and', 'boston', 'with', 'a', 'stopover', 'at', 'dallas', 'fort', 'worth']
# ['list', 'the', 'takeoffs', 'and', 'landings', 'at', 'general', 'mitchell', 'international']
# ['is', 'there', 'limo', 'service', 'at', 'pittsburgh', 'airport']
# ['how', 'much', 'is', 'a', 'first', 'class', 'ticket', 'from', 'boston', 'to', 'san', 'francisco']
# ['in', 'dallas', 'fort', 'worth', 'i', 'would', 'like', 'information', 'on', 'ground', 'transportation']
# ['i', "'d", 'like', 'flights', 'on', 'american', 'airlines', 'from', 'philadelphia', 'philadelphia', 'to', 'dallas', 'arriving', 'before', '1145', 'am']
# ['what', 'is', 'the', 'cost', 'of', 'a', 'round', 'trip', 'flight', 'from', 'pittsburgh', 'to', 'atlanta', 'beginning', 'on', 'april', 'twenty', 'fifth', 'and', 'returning', 'on', 'may', 'sixth']
# ['i', 'would', 'like', 'a', 'flight', 'from', 'washington', 'to', 'boston', 'leaving', 'at', '230', 'on', 'august', 'twentieth']
# ['i', "'d", 'like', 'to', 'fly', 'nonstop', 'from', 'atlanta', 'to', 'baltimore', 'and', 'get', 'there', 'at', '7', 'pm']
# 100%|█████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 146.29it/s]
# ['what', 'is', 'the', 'type', 'of', 'aircraft', 'for', 'united', 'flight', '21']
# ['can', 'you', 'give', 'me', 'information', 'on', 'transportation', 'from', 'the', 'airport', 'in', 'philadelphia', 'to', 'downtown', 'philadelphia']
# ['on', 'usa', 'air', 'how', 'many', 'flights', 'leaving', 'oakland', 'on', 'july', 'twenty', 'seventh', 'to', 'boston', 'nonstop']
# ['show', 'me', 'flights', 'between', 'new', 'york', 'city', 'and', 'las', 'vegas', 'on', 'sunday']
# 0.0

# %% [markdown]
# Sadly, you'll find that the coverage of the grammar is extraordinarily poor. That's because it is missing crucial parts of the grammar, especially phrases about _places_, which play a role in essentially every ATIS query. You'll need to complete the grammar before it can be useful.

# %% [markdown]
# ## Part 1: Finish the CFG for the ATIS dataset
#
# Consider the following query:

# %%
test_sentence_2 = tokenize("show me the united flights from boston")

# %%
test_sentence_2
# Out:
# ['show', 'me', 'the', 'united', 'flights', 'from', 'boston']

# %% [markdown]
# You'll notice that the grammar we distributed doesn't handle this query because it doesn't have a subgrammar for airline information (`"united"`) or for places (`"from boston"`).

# %%
len(list(atis_parser_distrib.parse(test_sentence_2)))
# Out:
# 0

# %% [markdown]
# Follow the instructions in the grammar file `data/grammar` to add further coverage to the grammar. (You can and should leave the `data/grammar_distrib3` copy alone and use it for reference.)
#
# We'll define a parser based on your modified grammar, so we can compare it against the distributed grammar. Once you've modified the grammar, this test sentence should have at least one parse.
#
# > You can search for "TODO" in `data/grammar` to find the two places to add grammar rules.

# %%
atis_grammar_expanded, _ = xform.read_augmented_grammar("grammar", path="data")
atis_parser_expanded = nltk.parse.BottomUpChartParser(atis_grammar_expanded)

parses = [p for p in atis_parser_expanded.parse(test_sentence_2)]
for parse in parses:
  parse.pretty_print()
# Out:
#                                                                 S
#                         ________________________________________|_______________________
#                        |                                                            NP_FLIGHT
#                        |                                                                |
#                        |                                                            NOM_FLIGHT
#                        |                                         _______________________|__________
#                        |                                        |                              NOM_FLIGHT
#                        |                                        |                                  |
#                    PREIGNORE                                    |                               N_FLIGHT
#         _______________|____________                            |             _____________________|_________
#        |                        PREIGNORE                      ADJ           |                               PP
#        |                ____________|____________               |            |                               |
#        |               |                     PREIGNORE     ADJ_AIRLINE    N_FLIGHT                        PP_PLACE
#        |               |                         |              |            |                      _________|_________
# PREIGNORESYMBOL PREIGNORESYMBOL           PREIGNORESYMBOL TERM_AIRBRAND TERM_FLIGHT             P_PLACE            TERM_PLACE
#        |               |                         |              |            |                     |                   |
#       show             me                       the           united      flights                 from               boston
#
#                                                     S
#                      _______________________________|____________
#                     |                                        NP_FLIGHT
#                     |                       _____________________|__________
#                     |                      |                            NOM_FLIGHT
#                     |                      |         _______________________|__________
#                     |                      |        |                              NOM_FLIGHT
#                     |                      |        |                                  |
#                     |                      |        |                               N_FLIGHT
#                     |                      |        |             _____________________|_________
#                 PREIGNORE                  |       ADJ           |                               PP
#         ____________|____________          |        |            |                               |
#        |                     PREIGNORE     |   ADJ_AIRLINE    N_FLIGHT                        PP_PLACE
#        |                         |         |        |            |                      _________|_________
# PREIGNORESYMBOL           PREIGNORESYMBOL DET TERM_AIRBRAND TERM_FLIGHT             P_PLACE            TERM_PLACE
#        |                         |         |        |            |                     |                   |
#       show                       me       the     united      flights                 from               boston

# %%
test_sentence_3 = tokenize("what is the most expensive one way flight from boston to atlanta on american airlines")
parses = [p for p in atis_parser_expanded.parse(test_sentence_3)]
for parse in parses:
  parse.pretty_print()

# %% [markdown]
# Once you're done adding to the grammar, to check your grammar, we'll compute the grammar's coverage of the ATIS training corpus as before.
# **This grammar should be expected to cover about half of the sentences in the first 50 sentences, and a third of the entire training corpus.**

# %%
coverage(lambda sent: 0 < len(list(atis_parser_expanded.parse(sent))),  # trick for turning parser into recognizer
         training_corpus, n=50)
# Out:
#  66%|█████████████████████████████████████████████████████▍                           | 33/50 [00:00<00:00, 122.80it/s]
# ['i', "'d", 'like', 'to', 'see', 'flights', 'from', 'baltimore', 'to', 'atlanta', 'that', 'arrive', 'before', 'noon', 'and', 'i', "'d", 'like', 'to', 'see', 'flights', 'from', 'denver', 'to', 'atlanta', 'that', 'arrive', 'before', 'noon']
# ['do', 'you', 'have', 'an', '819', 'flight', 'from', 'denver', 'to', 'san', 'francisco']
# ['how', 'can', 'i', 'get', 'from', 'boston', 'to', 'atlanta', 'and', 'back', 'in', 'the', 'same', 'day', 'and', 'have', 'the', 'most', 'hours', 'on', 'the', 'ground', 'in', 'atlanta']
# ['are', 'there', 'any', 'flights', 'between', 'pittsburgh', 'and', 'baltimore', 'using', 'a', 'j31', 'aircraft']
# ['what', 'does', 'd', '/s', 'stand', 'for', 'for', 'meals']
# ['i', 'need', 'the', 'cost', 'of', 'a', 'ticket', 'going', 'from', 'denver', 'to', 'baltimore', 'a', 'first', 'class', 'ticket', 'on', 'united', 'airlines']
# ['list', 'the', 'takeoffs', 'and', 'landings', 'at', 'general', 'mitchell', 'international']
# ['is', 'there', 'limo', 'service', 'at', 'pittsburgh', 'airport']
# ['how', 'much', 'is', 'a', 'first', 'class', 'ticket', 'from', 'boston', 'to', 'san', 'francisco']
# ['in', 'dallas', 'fort', 'worth', 'i', 'would', 'like', 'information', 'on', 'ground', 'transportation']
# ['i', "'d", 'like', 'flights', 'on', 'american', 'airlines', 'from', 'philadelphia', 'philadelphia', 'to', 'dallas', 'arriving', 'before', '1145', 'am']
# ['what', 'is', 'the', 'cost', 'of', 'a', 'round', 'trip', 'flight', 'from', 'pittsburgh', 'to', 'atlanta', 'beginning', 'on', 'april', 'twenty', 'fifth', 'and', 'returning', 'on', 'may', 'sixth']
# ['i', 'would', 'like', 'a', 'flight', 'from', 'washington', 'to', 'boston', 'leaving', 'at', '230', 'on', 'august', 'twentieth']
# ['i', "'d", 'like', 'to', 'fly', 'nonstop', 'from', 'atlanta', 'to', 'baltimore', 'and', 'get', 'there', 'at', '7', 'pm']
# 100%|█████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 110.89it/s]
# ['what', 'is', 'the', 'type', 'of', 'aircraft', 'for', 'united', 'flight', '21']
# ['can', 'you', 'give', 'me', 'information', 'on', 'transportation', 'from', 'the', 'airport', 'in', 'philadelphia', 'to', 'downtown', 'philadelphia']
# ['on', 'usa', 'air', 'how', 'many', 'flights', 'leaving', 'oakland', 'on', 'july', 'twenty', 'seventh', 'to', 'boston', 'nonstop']
# 0.46

# %% [markdown]
# # CFG recognition via the CKY algorithm
#
# Now we turn to implementing recognizers and parsers using the CKY algorithm. We start with a recognizer, which should return `True` or `False` if a grammar does or does not admit a sentence as grammatical.
#
# ## Converting the grammar to CNF for use by the CKY algorithm
#
# The CKY algorithm requires the grammar to be in Chomsky normal form (CNF). That is, only rules of the forms
# \begin{align*}
# A &\rightarrow B\, C\\
# A &\rightarrow a
# \end{align*}
# are allowed, where $A$, $B$, $C$ are nonterminals and $a$ is a terminal symbol.
#
# However, in some downstream applications (such as the next project segment) we want to use grammar rules of more general forms, such as $A \rightarrow B\, C\, D$. Indeed, the ATIS grammar you've been working on makes use of the additional expressivity beyond CNF.
#
# To satisfy both of these constraints, we will convert the grammar to CNF, parse using CKY, and then convert the returned parse trees back to the form of the original grammar. We provide some useful functions for performing these transformations in the file `scripts/transform.py`, already loaded above and imported as `xform`.
#
# To convert a grammar to CNF:
#
# `cnf_grammar, cnf_grammar_wunaries = xform.get_cnf_grammar(grammar)`
#
# To convert a tree output from CKY back to the original form of the grammar:
#
# `xform.un_cnf(tree, cnf_grammar_wunaries)`
#
# > We pass into `un_cnf` a version of the grammar before removing unary nonterminal productions, `cnf_grammar_wunaries`. The `cnf_grammar_wunaries` is returened as the second part of the returned value of `get_cnf_grammar` for just this purpose.

# %%
atis_grammar_cnf, atis_grammar_wunaries = xform.get_cnf_grammar(atis_grammar_expanded)
assert(atis_grammar_cnf.is_chomsky_normal_form())

# %% [markdown]
# In the next sections, you'll write your own recognizers and parsers based on the CKY algorithm that can operate on this grammar.

# %% [markdown]
# ## Part 2: Implement a CKY recognizer
#
# Implement a _recognizer_ using the CKY algorithm to determine if a sentence `tokens` is parsable. The labs and J&M Chapter 13, both of which provide appropriaste pseudo-code for CKY, should be useful references here.
#
# > **Hint:** Recall that you can get the production rules of a grammar using `grammar.productions()`.
#
# > Throughtout this project segment, you should use `grammar.start()` to get the special start symbol from the grammar instead of using `S`, since some grammar uses a different start symbol, such as `TOP`.

# %%
## TODO – Implement a CKY recognizer
def cky_recognize(grammar, tokens):
    assert(grammar.is_chomsky_normal_form())
    
    T = [[set() for i in range(len(tokens)+1)] for j in range(len(tokens)+1)]
    
    for j in range(1, len(tokens)+1):
        for prod in grammar.productions():
            
            if(prod.rhs()[0] == tokens[j-1]):
                T[j-1][j].add(prod.lhs())
        for length in range(2,j+1):
            i = j-length
            for split in range(i+1, j):
                for prod in grammar.productions():
                    if prod.rhs()[0] in T[i][split] and prod.rhs()[1] in T[split][j]:
                        T[i][j].add(prod.lhs())
    if grammar.start() in T[0][len(tokens)]: return True
    
    return False

# %% [markdown]
# You can test your recognizer on a few examples, both grammatical and ungrammatical, as below.

# %%
test_sentences = ["show me flights from boston",
                  "show me united flights before noon",
                  "are there any twa flights available tomorrow",
                  "show me flights united are there any"]

for sentence in test_sentences:
  recognized = "+" if cky_recognize(atis_grammar_cnf, tokenize(sentence)) else "-"
  print(f"{recognized:5}{sentence}")
# Out:
# +    show me flights from boston
# +    show me united flights before noon
# +    are there any twa flights available tomorrow
# -    show me flights united are there any

# %% [markdown]
# You can also verify that the CKY recognizer verifies the same coverage as the NLTK parser.

# %%
coverage(lambda sent: cky_recognize(atis_grammar_cnf, sent),
         training_corpus, n=50)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 50/50 [00:51<00:00,  1.02s/it]
# 0.46

# %% [markdown]
# ## Part 3: Implement a CKY parser
#
# In part 2, you implemented a context-free grammar recognizer. Next, you'll implement a _parser_.
#
# Implement the CKY algorithm for parsing with CFGs as a function `cky_parse`, which takes a grammar and a list of tokens and returns a single parse of the tokens as specified by the grammar, or `None` if there are no parses. You should only need to add a few lines of code to your CKY recognizer to achieve this, to implement the necessary back-pointers. The function should return an NLTK tree, which can be constructed using `Tree.fromstring`.
#
# A tree string will be like this example:
#
# ```
# "(S (A B) (C (D E) (F G)))"
# ```
#
# which corresponds to the following tree (drawn using tree.pretty_print()):
# ```
#      S
#   ___|___
#  |       C
#  |    ___|___
#  A   D       F
#  |   |       |
#  B   E       G
# ```
#
# > **Hint:** You may want to extract from a `Nonterminal` its corresponding string. The `Nonterminal.__str__` method or f-string `f'{Nonterminal}'` accomplishes this.

# %%
## TODO -- Implement a CKY parser
def cky_parse(grammar, tokens):
#   """Returns an NLTK parse tree of the list of tokens `tokens` as 
#   specified by the `grammar`. If there are multiple valid parses,
#   return any one of them.

#   Returns None if `tokens` is not parsable.
#   Implements the CKY algorithm, and therefore assumes `grammar` is in 
#   Chomsky normal form.
#   """
    assert(grammar.is_chomsky_normal_form())

    T = [[set() for i in range(len(tokens)+1)] for j in range(len(tokens)+1)]
    back = [[defaultdict(set) for i in range(len(tokens)+1)] for j in range(len(tokens)+1)]
    
    for j in range(1, len(tokens)+1):
        for prod in grammar.productions():
            
            if(prod.rhs()[0] == tokens[j-1]):
                T[j-1][j].add(prod.lhs())
        for length in range(2,j+1):
            i = j-length
            for split in range(i+1, j):
                for prod in grammar.productions():
                    if prod.rhs()[0] in T[i][split] and prod.rhs()[1] in T[split][j]:
                        T[i][j].add(prod.lhs())
                        back[i][j][prod.lhs()].add((split,prod.rhs()[0], prod.rhs()[1]))
    if not (grammar.start() in T[0][len(tokens)]): return None
    
    return Tree.fromstring(rec(0, len(tokens), tokens, back, grammar.start()))

# %%
def rec(start, end, tokens, back, k):
    if(start == end-1): return f'({k} {tokens[start]})'
    for triplette in back[start][end][k]:
        return f'({k} {rec(start, triplette[0], tokens, back, triplette[1])} {rec(triplette[0], end, tokens, back, triplette[2])})'

# %% [markdown]
# You can test your code on the test sentences provided above:

# %%
for sentence in test_sentences:
  tree = cky_parse(atis_grammar_cnf, tokenize(sentence))
  if not tree:
    print(f"failed to parse: {sentence}")
  else:
    xform.un_cnf(tree, atis_grammar_wunaries)
    tree.pretty_print()
# Out:
#                                                S
#                      __________________________|__________
#                     |                                 NP_FLIGHT
#                     |                                     |
#                     |                                 NOM_FLIGHT
#                     |                                     |
#                     |                                  N_FLIGHT
#                     |                           __________|_________
#                 PREIGNORE                      |                    PP
#         ____________|____________              |                    |
#        |                     PREIGNORE      N_FLIGHT             PP_PLACE
#        |                         |             |           _________|_________
# PREIGNORESYMBOL           PREIGNORESYMBOL TERM_FLIGHT  P_PLACE            TERM_PLACE
#        |                         |             |          |                   |
#       show                       me         flights      from               boston
#
#                                                 S
#                      ___________________________|_______________________
#                     |                                               NP_FLIGHT
#                     |                                                   |
#                     |                                               NOM_FLIGHT
#                     |                            _______________________|__________
#                     |                           |                              NOM_FLIGHT
#                     |                           |                                  |
#                     |                           |                               N_FLIGHT
#                     |                           |             _____________________|_________
#                     |                           |            |                               PP
#                     |                           |            |                               |
#                 PREIGNORE                      ADJ           |                            PP_TIME
#         ____________|____________               |            |                      _________|________
#        |                     PREIGNORE     ADJ_AIRLINE    N_FLIGHT                 |               NP_TIME
#        |                         |              |            |                     |                  |
# PREIGNORESYMBOL           PREIGNORESYMBOL TERM_AIRBRAND TERM_FLIGHT              P_TIME           TERM_TIME
#        |                         |              |            |                     |                  |
#       show                       me           united      flights                before              noon
#
#                                                     S
#                      _______________________________|____________
#                     |                                        NP_FLIGHT
#                     |                       _____________________|__________
#                     |                      |                            NOM_FLIGHT
#                     |                      |         _______________________|__________
#                     |                      |        |                              NOM_FLIGHT
#                     |                      |        |                                  |
#                     |                      |        |                               N_FLIGHT
#                     |                      |        |                        __________|_________
#                     |                      |        |                    N_FLIGHT                |
#                     |                      |        |             __________|__________          |
#                 PREIGNORE                  |       ADJ           |                     PP        PP
#         ____________|____________          |        |            |                     |         |
#        |                     PREIGNORE     |   ADJ_AIRLINE    N_FLIGHT              PP_CLASS  PP_DATE
#        |                         |         |        |            |                     |         |
# PREIGNORESYMBOL           PREIGNORESYMBOL DET TERM_AIRBRAND TERM_FLIGHT            ADJ_CLASS  NP_DATE
#        |                         |         |        |            |                     |         |
#       are                      there      any      twa        flights              available  tomorrow
#
# failed to parse: show me flights united are there any

# %% [markdown]
# You can also compare against the built-in NLTK parser that we constructed above:

# %%
for sentence in test_sentences:
  refparses = [p for p in atis_parser_expanded.parse(tokenize(sentence))]
  predparse = cky_parse(atis_grammar_cnf, tokenize(sentence))
  if predparse:
    xform.un_cnf(predparse, atis_grammar_wunaries)

  print('Reference parses:')
  for reftree in refparses:
    print(reftree)

  print('\nPredicted parse:')
  print(predparse)

  if (not predparse and len(refparses) == 0) or predparse in refparses:
    print("\nSUCCESS!")
  else:
    print("\nOops. No match.")
# Out:
# Reference parses:
# (S
#   (PREIGNORE (PREIGNORESYMBOL show) (PREIGNORE (PREIGNORESYMBOL me)))
#   (NP_FLIGHT
#     (NOM_FLIGHT
#       (N_FLIGHT
#         (N_FLIGHT (TERM_FLIGHT flights))
#         (PP (PP_PLACE (P_PLACE from) (TERM_PLACE boston)))))))
#
# Predicted parse:
# (S
#   (PREIGNORE (PREIGNORESYMBOL show) (PREIGNORE (PREIGNORESYMBOL me)))
#   (NP_FLIGHT
#     (NOM_FLIGHT
#       (N_FLIGHT
#         (N_FLIGHT (TERM_FLIGHT flights))
#         (PP (PP_PLACE (P_PLACE from) (TERM_PLACE boston)))))))
#
# SUCCESS!
# Reference parses:
# (S
#   (PREIGNORE (PREIGNORESYMBOL show) (PREIGNORE (PREIGNORESYMBOL me)))
#   (NP_FLIGHT
#     (NOM_FLIGHT
#       (ADJ (ADJ_AIRLINE (TERM_AIRBRAND united)))
#       (NOM_FLIGHT
#         (N_FLIGHT
#           (N_FLIGHT (TERM_FLIGHT flights))
#           (PP (PP_TIME (P_TIME before) (NP_TIME (TERM_TIME noon)))))))))
#
# Predicted parse:
# (S
#   (PREIGNORE (PREIGNORESYMBOL show) (PREIGNORE (PREIGNORESYMBOL me)))
#   (NP_FLIGHT
#     (NOM_FLIGHT
#       (ADJ (ADJ_AIRLINE (TERM_AIRBRAND united)))
#       (NOM_FLIGHT
#         (N_FLIGHT
#           (N_FLIGHT (TERM_FLIGHT flights))
#           (PP (PP_TIME (P_TIME before) (NP_TIME (TERM_TIME noon)))))))))
#
# SUCCESS!
# Reference parses:
# (S
#   (PREIGNORE
#     (PREIGNORESYMBOL are)
#     (PREIGNORE (PREIGNORESYMBOL there)))
#   (NP_FLIGHT
#     (DET any)
#     (NOM_FLIGHT
#       (ADJ (ADJ_AIRLINE (TERM_AIRBRAND twa)))
#       (NOM_FLIGHT
#         (N_FLIGHT
#           (N_FLIGHT
#             (N_FLIGHT (TERM_FLIGHT flights))
#             (PP (PP_CLASS (ADJ_CLASS available))))
#           (PP (PP_DATE (NP_DATE tomorrow))))))))
#
# Predicted parse:
# (S
#   (PREIGNORE
#     (PREIGNORESYMBOL are)
#     (PREIGNORE (PREIGNORESYMBOL there)))
#   (NP_FLIGHT
#     (DET any)
#     (NOM_FLIGHT
#       (ADJ (ADJ_AIRLINE (TERM_AIRBRAND twa)))
#       (NOM_FLIGHT
#         (N_FLIGHT
#           (N_FLIGHT
#             (N_FLIGHT (TERM_FLIGHT flights))
#             (PP (PP_CLASS (ADJ_CLASS available))))
#           (PP (PP_DATE (NP_DATE tomorrow))))))))
#
# SUCCESS!
# Reference parses:
#
# Predicted parse:
# None
#
# SUCCESS!

# %% [markdown]
# Again, we test the coverage as a way of verifying that your parser works consistently with the recognizer and the NLTK parser.

# %%
coverage(lambda sent: cky_parse(atis_grammar_cnf, sent),
         training_corpus, n=50)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 50/50 [00:48<00:00,  1.03it/s]
# 0.46

# %% [markdown]
# # Probabilistic CFG parsing via the CKY algorithm
#
# In practice, we want to work with grammars that cover nearly all the language we expect to come across for a given application. This leads to an explosion of rules and a large number of possible parses for any one sentence. To remove ambiguity between the different parses, it's desirable to move to probabilistic context-free grammars (PCFG). In this part of the assignment, you will construct a PCFG from training data, parse using a probabilistic version of CKY, and evaluate the quality of the resulting parses against gold trees.
#
# ## Part 4: PCFG construction
#
# Compared to CFGs, PCFGs need to assign probabilities to grammar rules. For this goal, you'll write a function `pcfg_from_trees` that takes a list of strings describing a corpus of trees and returns an NLTK PCFG trained on that set of trees.
#
# > We expect you to implement `pcfg_from_trees` directly. You should **not** use the [`induce_pcfg`](https://www.nltk.org/api/nltk.grammar.html#nltk.grammar.induce_pcfg) function in implementing your solution.
#
# We want the PCFG to be in CNF format because the probabilistic version of CKY that you'll implement next also requires the grammar to be in CNF. However, the gold trees are not in CNF form, so in this case you will need to convert the gold *trees* to CNF before building the PCFG from them. To accomplish this, you should use the `treetransforms` package from `nltk`, which includes functions for converting to and from CNF. In particular, you'll want to make use of `treetransforms.collapse_unary` followed by `treetransforms.chomsky_normal_form` to convert a tree to its binarized version. You can then get the counts for all of the productions used in the trees, and then normalize them to probabilities so that the probabilities of all rules with the same left-hand side sum to 1.
#
# We'll use the `pcfg_from_trees` function that you define later for parsing.
#
# > To convert an `nltk.Tree` object `t` to CNF, you can use the below code. Note that it's different from the `xform` functions we used before as we are converting _trees_, not _grammars_.
# >
# >    ```
# >    treetransforms.collapse_unary(t, collapsePOS=True)
# >    treetransforms.chomsky_normal_form(t) # After this the tree will be in CNF
# >    ```
#
# > To construct a PCFG with a given start state and set of productions, see [`nltk.grammar.PCFG`](https://www.nltk.org/api/nltk.grammar.html#nltk.grammar.PCFG).

# %%
def rule_counter(trees):
    res = {}
    for tree in trees:
        t = nltk.Tree.fromstring(tree)
        treetransforms.collapse_unary(t, collapsePOS=True)
        treetransforms.chomsky_normal_form(t)
        for prod in t.productions():
            if not (prod in res): res[prod] = 0
            res[prod] += 1
    return res
    #TODO
def lhs_counter(trees):
    rule_counts = rule_counter(trees)
    res = {}
    for prod in rule_counts.keys():
        if not (prod.lhs() in res): res[prod.lhs()] = 0
        res[prod.lhs()] += rule_counts[prod]
    return res
#TODO
def rule_probs(trees):
    rule_counts = rule_counter(trees)
    lhs_counts = lhs_counter(trees)
    res = {}
    for prod in rule_counts.keys():
        res[prod] = rule_counts[prod]/lhs_counts[prod.lhs()]
    return res

# %%
#TODO - Define a function to convert a set of trees to a PCFG in Chomsky normal form.
#You are not allowed to use any library functions except
#`treetransforms.collapse_unary` and `treetransforms.chomsky_normal_form`,
#write the logic by yourself.
def pcfg_from_trees(trees, start=Nonterminal('TOP')):
    prob_prod_list = []
    prod_dict = rule_probs(trees)
    for prod in prod_dict.keys():
        prob_prod_list += [ProbabilisticProduction(prod.lhs(),prod.rhs(), prob=prod_dict[prod])]
    return nltk.grammar.PCFG(start, prob_prod_list)
        
    
    


# After this the tree will be in CNF
#     """Returns an NLTK PCFG in CNF with rules and counts extracted from a set of trees.

#     The `trees` argument is a list of strings in the form interpretable by 
#     `Tree.fromstring`. The trees are converted to CNF using NLTK's 
#     `treetransforms.collapse_unary` and `treetransforms.chomsky_normal_form`.

#     The `start` argument is the start nonterminal symbol of the returned
#     grammar."""

# %% [markdown]
# We can now train a PCFG on the *train* split `train.trees` that we downloaded in the setup at the start of the notebook.

# %%
with open('data/train.trees') as file:
  ## Convert the probabilistic productions to an NLTK probabilistic CFG.
  pgrammar = pcfg_from_trees(file.readlines())
  print(pgrammar)
    
## Verify that the grammar is in CNF
assert(pgrammar.is_chomsky_normal_form())
# Out:
# C:\Users\barak\AppData\Local\Temp\ipykernel_2144\3381207002.py:5: DeprecationWarning:
#   Function collapse_unary() has been deprecated.  Import using `from
#   nltk.tree import collapse_unary` instead.
#   treetransforms.collapse_unary(t, collapsePOS=True)
# C:\Users\barak\AppData\Local\Temp\ipykernel_2144\3381207002.py:6: DeprecationWarning:
#   Function chomsky_normal_form() has been deprecated.  Import using
#   `from nltk.tree import chomsky_normal_form` instead.
#   treetransforms.chomsky_normal_form(t)
# Grammar with 1059 productions (start state = TOP)
#     TOP -> S+VP PUNC [0.208955]
#     S+VP -> VB NP [0.122302]
#     VB -> 'List' [0.0180723]
#     NP -> NP NP|<PP-PP-SBAR> [0.0057971]
#     NP -> DT NNS [0.0855072]
#     DT -> 'the' [0.626263]
#     NNS -> 'flights' [0.746411]
#     NP|<PP-PP-SBAR> -> PP NP|<PP-SBAR> [1.0]
#     PP -> IN NP+NNP [0.349927]
#     IN -> 'from' [0.452282]
#     NP+NNP -> 'Baltimore' [0.0421286]
#     NP|<PP-SBAR> -> PP SBAR [1.0]
#     PP -> TO NP+NNP [0.232796]
#     TO -> 'to' [1.0]
#     NP+NNP -> 'Seattle' [0.0133038]
#     SBAR -> WHNP+WDT S+VP [0.909091]
#     WHNP+WDT -> 'that' [0.428571]
#     S+VP -> VBP PP [0.0143885]
#     VBP -> 'stop' [0.0350877]
#     IN -> 'in' [0.10166]
#     NP+NNP -> 'Minneapolis' [0.0221729]
#     PUNC -> '.' [0.73774]
#     TOP -> SQ PUNC [0.0447761]
#     SQ -> VBZ SQ|<NP-VP> [0.0933333]
#     VBZ -> 'Does' [0.12069]
#     SQ|<NP-VP> -> NP VP [1.0]
#     NP -> DT NN [0.101449]
#     DT -> 'this' [0.0252525]
#     NN -> 'flight' [0.266904]
#     VP -> VB NP+NN [0.044586]
#     VB -> 'serve' [0.0421687]
#     NP+NN -> 'dinner' [0.27451]
#     PUNC -> '?' [0.26226]
#     TOP -> S PUNC [0.115139]
#     S -> NP+PRP VP [0.590164]
#     NP+PRP -> 'I' [0.323529]
#     VP -> VBP NP [0.10828]
#     VBP -> 'need' [0.140351]
#     NP -> NP NP|<PP-VP-VP> [0.00144928]
#     DT -> 'a' [0.156566]
#     NP|<PP-VP-VP> -> PP NP|<VP-VP> [1.0]
#     NP|<VP-VP> -> VP VP [1.0]
#     VP -> VBG PP [0.0955414]
#     VBG -> 'leaving' [0.264706]
#     VP -> VBG NP [0.0382166]
#     VBG -> 'making' [0.0294118]
#     NP -> NP PP [0.0405797]
#     NN -> 'stop' [0.024911]
#     VP -> VBP S+VP [0.0509554]
#     S+VP -> TO VP [0.151079]
#     VP -> VB S [0.0127389]
#     VB -> 'have' [0.0301205]
#     S -> NP+NN VP+VBN [0.0163934]
#     VP+VBN -> 'served' [1.0]
#     VBP -> 'have' [0.0614035]
#     NP -> NP SBAR [0.0188406]
#     NP -> CD NNS [0.00289855]
#     CD -> 'two' [0.0142857]
#     NNS -> 'friends' [0.00478469]
#     S+VP -> MD VP [0.0143885]
#     MD -> 'would' [0.346154]
#     VP -> VB S+VP [0.0828025]
#     VB -> 'like' [0.10241]
#     VP -> VB VP|<NP+PRP-PP-ADVP> [0.00636943]
#     VB -> 'visit' [0.0120482]
#     VP|<NP+PRP-PP-ADVP> -> NP+PRP VP|<PP-ADVP> [1.0]
#     NP+PRP -> 'me' [0.602941]
#     VP|<PP-ADVP> -> PP ADVP [1.0]
#     IN -> 'on' [0.143154]
#     NP+NNP -> 'Wednesday' [0.0243902]
#     ADVP -> ADVP+RB PP [0.285714]
#     ADVP+RB -> 'here' [0.125]
#     PP -> IN NP [0.288433]
#     NP -> NP+NNP NP [0.0130435]
#     NP+NNP -> 'Washington' [0.0177384]
#     NP -> NNP NNP [0.192754]
#     NNP -> 'D' [0.0122549]
#     NNP -> 'C' [0.0147059]
#     S -> S S|<CC-S> [0.0327869]
#     S -> NP VP [0.131148]
#     NP -> NP+CD PP [0.00144928]
#     NP+CD -> 'one' [1.0]
#     PP -> IN NP+PRP [0.00146413]
#     IN -> 'of' [0.0809129]
#     NP+PRP -> 'them' [0.00735294]
#     VP -> VBZ PP [0.0127389]
#     VBZ -> 'lives' [0.0344828]
#     NP+NNP -> 'Denver' [0.0332594]
#     S|<CC-S> -> CC S [1.0]
#     CC -> 'and' [0.804878]
#     NP -> DT JJ [0.00724638]
#     JJ -> 'other' [0.030303]
#     NP+NNP -> 'Miami' [0.0332594]
#     NP -> NP NP|<VP-SBAR> [0.00144928]
#     NN -> 'friend' [0.00355872]
#     NP|<VP-SBAR> -> VP SBAR [1.0]
#     VBG -> 'living' [0.0294118]
#     VP -> VB VP|<NP+PRP-ADVP> [0.00636943]
#     VP|<NP+PRP-ADVP> -> NP+PRP ADVP [1.0]
#     NP -> NP NP|<PP-PP-PP> [0.0115942]
#     NP|<PP-PP-PP> -> PP NP|<PP-PP> [1.0]
#     NP+NNP -> 'Indianapolis' [0.0243902]
#     NP|<PP-PP> -> PP PP [1.0]
#     NP+NNP -> 'Houston' [0.0354767]
#     NP -> NNP NP|<NNP-NNP> [0.0376812]
#     NNP -> 'T' [0.00980392]
#     NP|<NNP-NNP> -> NNP NNP [1.0]
#     NNP -> 'W' [0.0147059]
#     NNP -> 'A' [0.0245098]
#     DT -> 'The' [0.020202]
#     VP -> MD VP [0.121019]
#     MD -> 'should' [0.153846]
#     VP -> VB VP|<PP-NP+NN> [0.00636943]
#     VB -> 'arrive' [0.0240964]
#     VP|<PP-NP+NN> -> PP NP+NN [1.0]
#     IN -> 'at' [0.0207469]
#     NP -> QP RB [0.00434783]
#     QP -> RB CD [0.214286]
#     RB -> 'around' [0.0566038]
#     CD -> 'eleven' [0.0142857]
#     RB -> 'a.m' [0.150943]
#     NP+NN -> 'tomorrow' [0.117647]
#     NP -> NP NP|<PP-PP-NP> [0.00434783]
#     NP|<PP-PP-NP> -> PP NP|<PP-NP> [1.0]
#     NP+NNP -> 'Atlanta' [0.0133038]
#     NP|<PP-NP> -> PP NP [1.0]
#     PP -> TO NP [0.0849195]
#     NP+NNP -> 'Charlotte' [0.0199557]
#     NNP -> 'North' [0.00245098]
#     NNP -> 'Carolina' [0.00245098]
#     NP -> JJ NNP [0.00434783]
#     JJ -> 'next' [0.0909091]
#     NNP -> 'Monday' [0.0122549]
#     VP -> VB VP|<PP-PP> [0.0509554]
#     VP|<PP-PP> -> PP PP [1.0]
#     CD -> 'five' [0.128571]
#     RB -> 'p.m' [0.415094]
#     VP -> VB PP [0.044586]
#     VB -> 'return' [0.0120482]
#     NP+NNP -> 'Tuesday' [0.00886918]
#     NP -> DT NP|<NN-NN> [0.0115942]
#     NP|<NN-NN> -> NN NN [1.0]
#     NN -> 'return' [0.00711744]
#     VB -> 'leave' [0.0240964]
#     CD -> 'seven' [0.0785714]
#     TOP -> SBARQ PUNC [0.217484]
#     SBARQ -> WHNP SQ [0.0784314]
#     WHNP -> WHNP ADJP+JJ [0.010989]
#     WHNP -> WRB RB [0.0549451]
#     WRB -> 'How' [1.0]
#     RB -> 'much' [0.0943396]
#     ADJP+JJ -> 'extra' [0.111111]
#     SQ -> MD SQ|<NP-VP+VB> [0.0266667]
#     SQ|<NP-VP+VB> -> NP VP+VB [1.0]
#     NP -> DT NP|<JJ-NN-NN> [0.0057971]
#     NP|<JJ-NN-NN> -> JJ NP|<NN-NN> [1.0]
#     JJ -> 'first' [0.151515]
#     NN -> 'class' [0.0498221]
#     NN -> 'fare' [0.0676157]
#     VP+VB -> 'cost' [0.5]
#     NN -> 'coach' [0.00711744]
#     VP -> VB NP [0.0955414]
#     VB -> 'find' [0.0120482]
#     S+VP -> VBZ S+VP|<PP-PP> [0.0143885]
#     VBZ -> 'goes' [0.0172414]
#     S+VP|<PP-PP> -> PP PP [1.0]
#     NP+NNP -> 'Boston' [0.0133038]
#     NP+NNP -> 'Orlando' [0.0310421]
#     VP -> TO VP [0.00636943]
#     VP -> VP VP|<CC-VP> [0.0191083]
#     VB -> 'be' [0.0120482]
#     NNP -> 'United' [0.0147059]
#     NNP -> 'Airlines' [0.0416667]
#     VP|<CC-VP> -> CC VP [1.0]
#     NNP -> 'San' [0.0735294]
#     NNP -> 'Jose' [0.0171569]
#     IN -> 'around' [0.0124481]
#     NP -> CD RB [0.0304348]
#     CD -> 'ten' [0.0785714]
#     VP -> VB VP|<PRT+RP-NP> [0.00636943]
#     VP|<PRT+RP-NP> -> PRT+RP NP [1.0]
#     PRT+RP -> 'out' [1.0]
#     NN -> 'number' [0.0177936]
#     IN -> 'for' [0.0103734]
#     NP -> DT NP|<NNP-NN> [0.00289855]
#     NP|<NNP-NN> -> NNP NN [1.0]
#     VBZ -> 'arrives' [0.0344828]
#     S+VP -> VB S+VP|<NP+PRP-NP> [0.52518]
#     VB -> 'Show' [0.518072]
#     S+VP|<NP+PRP-NP> -> NP+PRP NP [1.0]
#     NP -> NP VP [0.0057971]
#     NP -> PDT NP|<DT-NNS> [0.00434783]
#     PDT -> 'all' [1.0]
#     NP|<DT-NNS> -> DT NNS [1.0]
#     VP -> VBG NP+NNP [0.00636943]
#     S+VP -> VB S+VP|<PP-PP> [0.00719424]
#     VB -> 'go' [0.0120482]
#     SBARQ -> PP SBARQ|<WHNP+WHNP-SQ+VP> [0.00980392]
#     IN -> 'Of' [0.00207469]
#     DT -> 'those' [0.00505051]
#     SBARQ|<WHNP+WHNP-SQ+VP> -> WHNP+WHNP SQ+VP [1.0]
#     WHNP+WHNP -> WDT NNS [0.9]
#     WDT -> 'which' [0.0120482]
#     NNS -> 'ones' [0.00956938]
#     SQ+VP -> VBP PP [0.14]
#     DT -> 'that' [0.020202]
#     SBARQ -> WHNP+WP SQ [0.196078]
#     WHNP+WP -> 'What' [1.0]
#     SQ -> VBP NP [0.0666667]
#     VBP -> 'are' [0.236842]
#     NP -> NP NP|<PP-PP> [0.0492754]
#     NP+NNP -> 'Milwaukee' [0.0421286]
#     NP+NNP -> 'Tampa' [0.0310421]
#     SBARQ -> WHNP SQ+VP [0.411765]
#     WHNP -> WHNP+WDT PP [0.186813]
#     WHNP+WDT -> 'Which' [0.571429]
#     PP -> IN NP+DT [0.0161054]
#     NP+DT -> 'these' [0.533333]
#     NP+NNP -> 'Nashville' [0.037694]
#     NP+NNP -> 'Newark' [0.0620843]
#     NNP -> 'New' [0.0612745]
#     NNP -> 'Jersey' [0.00980392]
#     NNP -> 'Ontario' [0.00245098]
#     NNP -> 'International' [0.00490196]
#     NNP -> 'Saturday' [0.00245098]
#     SQ+VP -> VP SQ+VP|<CC-VP> [0.04]
#     VP -> VBP PP [0.0318471]
#     VBP -> 'leave' [0.0964912]
#     PP -> IN NP+NN [0.0131772]
#     IN -> 'after' [0.033195]
#     NP+NN -> 'noon' [0.117647]
#     SQ+VP|<CC-VP> -> CC VP [1.0]
#     NP+NNP -> 'Phoenix' [0.0421286]
#     NP+NNP -> 'Montreal' [0.0177384]
#     NP+NNP -> 'Chicago' [0.0199557]
#     S+VP -> VB S+VP|<NP+PRP-PP> [0.00719424]
#     VB -> 'Tell' [0.0060241]
#     S+VP|<NP+PRP-PP> -> NP+PRP PP [1.0]
#     IN -> 'about' [0.0124481]
#     NP -> DT NP|<NN-NN-NN> [0.00289855]
#     NP|<NN-NN-NN> -> NN NP|<NN-NN> [1.0]
#     NN -> 'ground' [0.0177936]
#     NN -> 'transportation' [0.024911]
#     TOP -> FRAG PUNC [0.0597015]
#     FRAG -> X PP [0.0689655]
#     X -> WP IN [0.666667]
#     WP -> 'What' [0.75]
#     SBARQ -> WHNP+WHNP SQ [0.186275]
#     WDT -> 'What' [0.915663]
#     SQ -> VBP SQ|<NP+PRP-VP> [0.04]
#     VBP -> 'do' [0.0438596]
#     SQ|<NP+PRP-VP> -> NP+PRP VP [1.0]
#     NP+PRP -> 'you' [0.0441176]
#     S+VP -> VB NP+PRP [0.0143885]
#     VB -> 'Thank' [0.0120482]
#     WHNP -> WDT NN [0.032967]
#     WDT -> 'what' [0.0120482]
#     NN -> 'time' [0.00711744]
#     SQ -> VBZ NP+PRP [0.0266667]
#     VBZ -> 'is' [0.534483]
#     NP+PRP -> 'it' [0.0147059]
#     SBARQ -> WHNP+WDT SQ [0.0490196]
#     S+VP -> VBP NP [0.0143885]
#     VBP -> 'make' [0.0175439]
#     VB -> 'Book' [0.0060241]
#     VB -> 'travel' [0.0180723]
#     NP -> CD NP|<CC-CD-RB> [0.00289855]
#     NP|<CC-CD-RB> -> CC NP|<CD-RB> [1.0]
#     CC -> 'or' [0.170732]
#     NP|<CD-RB> -> CD RB [1.0]
#     NP -> DT NP|<JJ-NN> [0.0130435]
#     NP|<JJ-NN> -> JJ NN [1.0]
#     NN -> 'one' [0.00711744]
#     SQ -> VBZ NP [0.293333]
#     NN -> 'aircraft' [0.00711744]
#     VP -> VBN PP [0.0191083]
#     VBN -> 'used' [0.333333]
#     IN -> 'by' [0.00622407]
#     VP -> VBP ADJP [0.00636943]
#     VBP -> 'am' [0.00877193]
#     ADJP -> JJ PP [0.2]
#     JJ -> 'interested' [0.0151515]
#     NP+NNP -> 'Cincinnati' [0.0199557]
#     NP+NNP -> 'Burbank' [0.0133038]
#     VP -> VB NP+NNP [0.0127389]
#     NP+NNP -> 'American' [0.00443459]
#     NN -> 'afternoon' [0.0284698]
#     VB -> 'know' [0.0060241]
#     NP -> DT NX [0.00144928]
#     NX -> NX+NN NX|<CC-NX> [0.5]
#     NX+NN -> 'aircraft' [1.0]
#     NX|<CC-NX> -> CC NX [1.0]
#     NX -> NN NN [0.5]
#     NP -> NP NP|<PP-PP-NP+NN> [0.00144928]
#     NP|<PP-PP-NP+NN> -> PP NP|<PP-NP+NN> [1.0]
#     NNP -> 'Los' [0.0269608]
#     NNP -> 'Angeles' [0.0269608]
#     NP|<PP-NP+NN> -> PP NP+NN [1.0]
#     NP+NN -> 'today' [0.0196078]
#     NP -> NP NP|<PP-PP-VP> [0.0101449]
#     NP|<PP-PP-VP> -> PP NP|<PP-VP> [1.0]
#     NP|<PP-VP> -> PP VP [1.0]
#     NP -> NN NN [0.0130435]
#     NN -> 'today' [0.00355872]
#     NN -> 'evening' [0.0391459]
#     NN -> 'tomorrow' [0.0106762]
#     SQ -> VBP SQ|<NP-VP> [0.0266667]
#     VBP -> 'Do' [0.0350877]
#     DT -> 'any' [0.00505051]
#     VB -> 'stop' [0.0060241]
#     WHNP -> WDT NNS [0.67033]
#     NNS -> 'meals' [0.0191388]
#     SQ+VP -> VBP VP [0.02]
#     VBN -> 'served' [0.666667]
#     DT -> 'these' [0.0555556]
#     VP -> VB VP|<PP-X+TO-PP> [0.00636943]
#     VP|<PP-X+TO-PP> -> PP VP|<X+TO-PP> [1.0]
#     VP|<X+TO-PP> -> X+TO PP [1.0]
#     X+TO -> 'to' [1.0]
#     NP -> NP+NNP NP+NNP [0.00724638]
#     NP+NNP -> 'Tacoma' [0.0221729]
#     VB -> 'fly' [0.0301205]
#     JJ -> 'ninth' [0.0151515]
#     NP+NNP -> 'July' [0.00665188]
#     SBARQ -> WHADVP+WRB SQ [0.00980392]
#     WHADVP+WRB -> 'Where' [1.0]
#     SQ -> VBP SQ|<NP-VP+VB> [0.0266667]
#     VP+VB -> 'stop' [0.166667]
#     NN -> 'cost' [0.00711744]
#     JJ -> 'round' [0.227273]
#     NN -> 'trip' [0.0604982]
#     NP+NNP -> 'Alaska' [0.00221729]
#     S -> INTJ+UH VP [0.0655738]
#     INTJ+UH -> 'Please' [0.25]
#     VB -> 'list' [0.0240964]
#     DT -> 'all' [0.0505051]
#     NNS -> 'details' [0.00478469]
#     NP -> DT NP|<NNP-NNP-CD-CD-NN> [0.00144928]
#     NP|<NNP-NNP-CD-CD-NN> -> NNP NP|<NNP-CD-CD-NN> [1.0]
#     NP|<NNP-CD-CD-NN> -> NNP NP|<CD-CD-NN> [1.0]
#     NNP -> 'P' [0.00245098]
#     NP|<CD-CD-NN> -> CD NP|<CD-NN> [1.0]
#     CD -> 'fifty' [0.0428571]
#     NP|<CD-NN> -> CD NN [1.0]
#     IN -> 'between' [0.026971]
#     NN -> 'type' [0.00711744]
#     NNP -> 'American' [0.0245098]
#     S -> INTJ+UH S|<NP+PRP-VP> [0.0163934]
#     INTJ+UH -> 'Okay' [0.166667]
#     S|<NP+PRP-VP> -> NP+PRP VP [1.0]
#     MD -> "'d" [0.384615]
#     VB -> 'make' [0.0060241]
#     NN -> 'reservation' [0.00711744]
#     NP -> NN NP|<CD-CD-CD> [0.00289855]
#     NP|<CD-CD-CD> -> CD NP|<CD-CD> [1.0]
#     CD -> 'six' [0.0785714]
#     NP|<CD-CD> -> CD CD [1.0]
#     CD -> 'oh' [0.0142857]
#     NP+NNP -> 'Delta' [0.00221729]
#     NN -> 'discount' [0.00355872]
#     TOP -> FRAG+NP PUNC [0.223881]
#     FRAG+NP -> NP PP [0.0571429]
#     JJ -> 'eighth' [0.0151515]
#     FRAG -> NP INTJ+UH [0.0344828]
#     NP -> NNP JJ [0.00289855]
#     NNP -> 'July' [0.00490196]
#     JJ -> 'sixteenth' [0.0151515]
#     INTJ+UH -> 'please' [0.166667]
#     NP -> NP NP|<NP+NN-PP-PP> [0.00144928]
#     NP|<NP+NN-PP-PP> -> NP+NN NP|<PP-PP> [1.0]
#     NNP -> 'Diego' [0.0196078]
#     NP+NNP -> 'Toronto' [0.0221729]
#     NP -> NP NP|<NP+NN-PP-PP-PP> [0.00144928]
#     NP|<NP+NN-PP-PP-PP> -> NP+NN NP|<PP-PP-PP> [1.0]
#     NP+NNP -> 'Columbus' [0.0221729]
#     IN -> 'with' [0.0124481]
#     NN -> 'stopover' [0.00355872]
#     SQ+VP -> VBP NP [0.08]
#     NP -> DT NP|<JJS-NN> [0.0101449]
#     NP|<JJS-NN> -> JJS NN [1.0]
#     JJS -> 'longest' [0.03125]
#     NN -> 'layover' [0.00355872]
#     SQ -> VBZ SQ|<NP+NN-VP> [0.0133333]
#     VBZ -> 'Is' [0.12069]
#     SQ|<NP+NN-VP> -> NP+NN VP [1.0]
#     NP -> NP NP|<CC-NP> [0.0115942]
#     NN -> 'leg' [0.00711744]
#     NP|<CC-NP> -> CC NP [1.0]
#     JJ -> 'second' [0.0151515]
#     SQ -> VBZ SQ|<NP-PP> [0.0133333]
#     SQ|<NP-PP> -> NP PP [1.0]
#     SQ -> VBZ SQ|<NP+NP+EX-NP> [0.0266667]
#     SQ|<NP+NP+EX-NP> -> NP+NP+EX NP [1.0]
#     NP+NP+EX -> 'there' [1.0]
#     NP -> NP NP|<NP-PP-X+TO-PP> [0.00144928]
#     NP|<NP-PP-X+TO-PP> -> NP NP|<PP-X+TO-PP> [1.0]
#     NN -> 'morning' [0.0604982]
#     NP|<PP-X+TO-PP> -> PP NP|<X+TO-PP> [1.0]
#     NP|<X+TO-PP> -> X+TO PP [1.0]
#     NP -> NP NP|<PP-PP-PP-NP+NN> [0.00144928]
#     NP|<PP-PP-PP-NP+NN> -> PP NP|<PP-PP-NP+NN> [1.0]
#     NP -> NP NP|<NN-CD-CD-CD> [0.00144928]
#     NP -> NNP POS [0.00289855]
#     POS -> "'s" [1.0]
#     NP|<NN-CD-CD-CD> -> NN NP|<CD-CD-CD> [1.0]
#     CD -> 'eighteen' [0.00714286]
#     CD -> 'twenty' [0.0142857]
#     TOP -> INTJ+UH PUNC [0.00426439]
#     INTJ+UH -> 'Thanks' [0.166667]
#     NNP -> 'Kansas' [0.0343137]
#     NNP -> 'City' [0.0710784]
#     VBP -> 'prefer' [0.00877193]
#     NP -> NP NP|<NP-PP-PP> [0.00144928]
#     NP|<NP-PP-PP> -> NP NP|<PP-PP> [1.0]
#     NN -> 'day' [0.0106762]
#     NP -> DT NP|<NN-NNS> [0.00869565]
#     NP|<NN-NNS> -> NN NNS [1.0]
#     VP -> VB VP|<ADVP-NP> [0.00636943]
#     VP|<ADVP-NP> -> ADVP NP [1.0]
#     ADVP -> RB PP [0.142857]
#     RB -> 'back' [0.0188679]
#     JJS -> 'latest' [0.125]
#     SBAR -> WHNP+WDT S [0.0454545]
#     S -> NP+NNP VP+VBZ [0.0163934]
#     NP+NNP -> 'Continental' [0.00221729]
#     VP+VBZ -> 'has' [1.0]
#     WDT -> 'Which' [0.060241]
#     VBP -> 'go' [0.0789474]
#     IN -> 'through' [0.00207469]
#     NNP -> 'York' [0.0514706]
#     NP -> DT NP|<CD-CD-NN> [0.00144928]
#     CD -> 'twelve' [0.0357143]
#     CD -> 'fourteen' [0.00714286]
#     NP+NN -> 'lunch' [0.0588235]
#     NP -> DT NP|<CD-CD-CD-NN> [0.00144928]
#     NP|<CD-CD-CD-NN> -> CD NP|<CD-CD-NN> [1.0]
#     CD -> 'thirty' [0.0785714]
#     FRAG -> X NP [0.0689655]
#     X -> WRB IN [0.166667]
#     S+VP -> VBZ PP [0.0215827]
#     VBZ -> 'leaves' [0.0689655]
#     NP -> CD NP|<CD-CD> [0.00434783]
#     VP -> VBD NP [0.00636943]
#     VBD -> 'meant' [1.0]
#     NP -> CD NP|<CD-CD-RB> [0.00144928]
#     NP|<CD-CD-RB> -> CD NP|<CD-RB> [1.0]
#     VBP -> "'m" [0.00877193]
#     NNP -> 'Las' [0.0588235]
#     NNP -> 'Vegas' [0.0588235]
#     NP+NNP -> 'Sunday' [0.0177384]
#     S -> PP S|<NP+PRP-VP> [0.0327869]
#     IN -> 'On' [0.00829876]
#     NP+NNP -> 'Monday' [0.0110865]
#     NP+NNP -> 'Detroit' [0.0133038]
#     NP+NNP -> 'Michigan' [0.00221729]
#     SQ -> MD SQ|<NP+PRP-VP> [0.0266667]
#     MD -> 'Can' [0.0769231]
#     NP -> DT NP|<JJ-NN-NNS> [0.00289855]
#     NP|<JJ-NN-NNS> -> JJ NP|<NN-NNS> [1.0]
#     JJ -> 'nonstop' [0.151515]
#     NP+NNP -> 'Thursday' [0.00886918]
#     VP -> VB VP|<ADVP+RB-PP-ADJP> [0.00636943]
#     VP|<ADVP+RB-PP-ADJP> -> ADVP+RB VP|<PP-ADJP> [1.0]
#     ADVP+RB -> 'home' [0.0625]
#     VP|<PP-ADJP> -> PP ADJP [1.0]
#     ADJP -> RB ADJP|<RB-PP> [0.2]
#     RB -> 'as' [0.0188679]
#     ADJP|<RB-PP> -> RB PP [1.0]
#     RB -> 'early' [0.0188679]
#     PP -> IN ADJP+JJ [0.00146413]
#     IN -> 'as' [0.00207469]
#     ADJP+JJ -> 'possible' [0.111111]
#     VP -> VB VP|<PP-PP-NP> [0.00636943]
#     VP|<PP-PP-NP> -> PP VP|<PP-NP> [1.0]
#     VP|<PP-NP> -> PP NP [1.0]
#     VP -> VB VP|<NP+PRP-NP> [0.0191083]
#     VB -> 'show' [0.0180723]
#     VP|<NP+PRP-NP> -> NP+PRP NP [1.0]
#     NP -> NN NNS [0.0101449]
#     S+VP -> VBP NP+NN [0.0143885]
#     VBP -> 'serve' [0.0438596]
#     FRAG -> NP FRAG|<NP-NP-NP> [0.0344828]
#     NP -> NP NP|<CC-ADVP+RB-NP> [0.00144928]
#     NP -> NP+NN NP|<PP-PP> [0.0057971]
#     NP+NN -> 'Flight' [0.0784314]
#     NNP -> 'Saint' [0.0196078]
#     NNP -> 'Petersburg' [0.00735294]
#     NP|<CC-ADVP+RB-NP> -> CC NP|<ADVP+RB-NP> [1.0]
#     NP|<ADVP+RB-NP> -> ADVP+RB NP [1.0]
#     ADVP+RB -> 'also' [0.0625]
#     NP+NN -> 'flight' [0.0588235]
#     FRAG|<NP-NP-NP> -> NP FRAG|<NP-NP> [1.0]
#     NP -> NP+NN PP [0.00144928]
#     NP+NN -> 'stay' [0.0196078]
#     FRAG|<NP-NP> -> NP NP [1.0]
#     NP -> JJ NN [0.015942]
#     JJ -> 'direct' [0.0151515]
#     JJ -> 'same' [0.0151515]
#     NN -> 'airline' [0.00711744]
#     FRAG+NP -> NP FRAG+NP|<PP-PP> [0.152381]
#     NP -> NP+NN NP|<CC-NP> [0.00144928]
#     NP+NN -> 'Airline' [0.0392157]
#     FRAG+NP|<PP-PP> -> PP PP [1.0]
#     TOP -> FRAG+NP+NN PUNC [0.00426439]
#     FRAG+NP+NN -> 'Tomorrow' [0.5]
#     FRAG+NP -> NP FRAG+NP|<PP-PP-NP+NN> [0.00952381]
#     NN -> 'Flight' [0.0106762]
#     NNS -> 'numbers' [0.0143541]
#     FRAG+NP|<PP-PP-NP+NN> -> PP FRAG+NP|<PP-NP+NN> [1.0]
#     FRAG+NP|<PP-NP+NN> -> PP NP+NN [1.0]
#     FRAG+NP -> NP FRAG+NP|<PP-PP-PP> [0.0285714]
#     FRAG+NP|<PP-PP-PP> -> PP FRAG+NP|<PP-PP> [1.0]
#     NNP -> 'Long' [0.00735294]
#     NNP -> 'Beach' [0.00735294]
#     NP -> NNP NP|<CD-CD> [0.00144928]
#     NNP -> 'June' [0.00245098]
#     S -> NP+PRP S|<ADVP+RB-VP> [0.0163934]
#     S|<ADVP+RB-VP> -> ADVP+RB VP [1.0]
#     ADVP+RB -> 'actually' [0.0625]
#     VBP -> 'want' [0.0263158]
#     NP+NNP -> 'Ontario' [0.0133038]
#     VP -> VBP FRAG [0.00636943]
#     VBP -> 'mean' [0.00877193]
#     FRAG -> NP+NNP FRAG|<PP-PP> [0.0689655]
#     FRAG|<PP-PP> -> PP PP [1.0]
#     NP+NNP -> 'Westchester' [0.00221729]
#     IN -> 'via' [0.00622407]
#     SQ+VP -> VBZ NP+NN [0.02]
#     VBZ -> 'serves' [0.0344828]
#     VBP -> 'plan' [0.00877193]
#     NP -> CD CD [0.00289855]
#     NP -> NNP NN [0.0173913]
#     S -> ADVP+RB S|<NP+PRP-VP> [0.0327869]
#     ADVP+RB -> 'Now' [0.125]
#     NNP -> 'Tuesday' [0.00245098]
#     NP+NNP -> 'Oakland' [0.0155211]
#     SQ+VP -> VBP NP+NN [0.08]
#     NN -> 'dinner' [0.0213523]
#     SQ+VP -> VBP ADVP+RB [0.02]
#     VBP -> 'depart' [0.0614035]
#     ADVP+RB -> 'last' [0.0625]
#     SQ+VP -> VBZ ADJP+JJ [0.06]
#     ADJP+JJ -> 'last' [0.333333]
#     SQ+VP -> VBP ADVP+RBS [0.02]
#     ADVP+RBS -> 'latest' [1.0]
#     NP -> DT NP|<JJS-NN-NN> [0.00289855]
#     NP|<JJS-NN-NN> -> JJS NP|<NN-NN> [1.0]
#     S+VP -> VB S+VP|<NP+PRP-NP-INTJ+UH> [0.0143885]
#     S+VP|<NP+PRP-NP-INTJ+UH> -> NP+PRP S+VP|<NP-INTJ+UH> [1.0]
#     S+VP|<NP-INTJ+UH> -> NP INTJ+UH [1.0]
#     SBARQ -> WHNP+WDT SQ+VP [0.0588235]
#     SQ+VP -> VBZ ADVP+RBS [0.02]
#     WHNP+WHNP -> WHADJP NNS [0.1]
#     WHADJP -> WRB JJ [1.0]
#     JJ -> 'many' [0.0454545]
#     NNS -> 'fares' [0.0717703]
#     SQ -> VBP SQ|<NP+NP+EX-NP-PP-PP> [0.0266667]
#     SQ|<NP+NP+EX-NP-PP-PP> -> NP+NP+EX SQ|<NP-PP-PP> [1.0]
#     SQ|<NP-PP-PP> -> NP SQ|<PP-PP> [1.0]
#     NP -> CD NN [0.0144928]
#     CD -> 'one' [0.185714]
#     NN -> 'way' [0.0284698]
#     SQ|<PP-PP> -> PP PP [1.0]
#     JJS -> 'earliest' [0.09375]
#     NN -> 'lunch' [0.00711744]
#     VBG -> 'arriving' [0.352941]
#     WHNP -> WHNP PP [0.032967]
#     NP+NN -> 'aircraft' [0.0196078]
#     SQ+VP -> VBP SQ+VP|<PP-PP> [0.12]
#     SQ+VP|<PP-PP> -> PP PP [1.0]
#     NP+NNP -> 'Dallas' [0.0310421]
#     SQ+VP -> VBP SQ+VP|<PP-PP-PP> [0.12]
#     SQ+VP|<PP-PP-PP> -> PP SQ+VP|<PP-PP> [1.0]
#     TOP -> X+SBARQ PUNC [0.0021322]
#     X+SBARQ -> WHNP SQ+VP [1.0]
#     SQ+VP -> VBP PP+IN [0.02]
#     PP+IN -> 'from' [1.0]
#     NP+NNP -> 'Philadelphia' [0.0177384]
#     NNP -> 'Francisco' [0.0367647]
#     NP -> DT NP|<NN-SYM-CD> [0.00144928]
#     NP|<NN-SYM-CD> -> NN NP|<SYM-CD> [1.0]
#     NN -> 'abbreviation' [0.00355872]
#     NP|<SYM-CD> -> SYM CD [1.0]
#     SYM -> 'D' [0.166667]
#     SQ+VP -> VBP ADJP+JJ [0.02]
#     ADJP+JJ -> 'nonstop' [0.222222]
#     NP -> QP NN [0.00289855]
#     QP -> IN QP|<JJS-CD> [0.142857]
#     QP|<JJS-CD> -> JJS CD [1.0]
#     JJS -> 'least' [0.0625]
#     VP -> VB VP|<PP-PP-PP> [0.00636943]
#     VP|<PP-PP-PP> -> PP VP|<PP-PP> [1.0]
#     NP+NNP -> 'Pittsburgh' [0.0266075]
#     S+VP -> VBZ NP [0.00719424]
#     NN -> 'snack' [0.00355872]
#     NP -> NP NP|<SBAR-PP> [0.00144928]
#     NP|<SBAR-PP> -> SBAR PP [1.0]
#     NP -> JJ NNS [0.00724638]
#     NNS -> 'airlines' [0.0143541]
#     VBP -> 'fly' [0.0175439]
#     VP -> VBP VP|<NP+NNP-PP> [0.00636943]
#     VP|<NP+NNP-PP> -> NP+NNP PP [1.0]
#     VP -> VBP VP|<PP-PP> [0.00636943]
#     VBP -> 'arrive' [0.0350877]
#     SQ+VP -> VBP SQ+VP|<NP+NNP-PP> [0.06]
#     SQ+VP|<NP+NNP-PP> -> NP+NNP PP [1.0]
#     NN -> 'noon' [0.00711744]
#     SQ -> X SQ|<VBZ-NP-ADJP+JJ> [0.0133333]
#     X -> VBZ NP+DT [0.166667]
#     NP+DT -> 'this' [0.0666667]
#     SQ|<VBZ-NP-ADJP+JJ> -> VBZ SQ|<NP-ADJP+JJ> [1.0]
#     SQ|<NP-ADJP+JJ> -> NP ADJP+JJ [1.0]
#     SQ -> VBZ SQ|<NP-NP> [0.0266667]
#     SQ|<NP-NP> -> NP NP [1.0]
#     NP -> NNP NP|<NNP-NN-CD-CD> [0.00289855]
#     NP|<NNP-NN-CD-CD> -> NNP NP|<NN-CD-CD> [1.0]
#     NP|<NN-CD-CD> -> NN NP|<CD-CD> [1.0]
#     CD -> 'four' [0.0214286]
#     NP -> NP+NNP NP|<CC-NP> [0.00869565]
#     NNP -> 'Salt' [0.0147059]
#     NNP -> 'Lake' [0.0147059]
#     NP -> NP ADJP+JJ [0.00144928]
#     ADJP+JJ -> 'available' [0.111111]
#     TOP -> SBAR PUNC [0.0021322]
#     SBAR -> WHNP SQ [0.0454545]
#     WHNP -> WHADJP NNS [0.010989]
#     NNS -> 'stops' [0.0191388]
#     SQ -> VBP NP+NP+EX [0.0133333]
#     DT -> 'Any' [0.00505051]
#     NNS -> 'stopovers' [0.00956938]
#     NP -> NNP NP|<CD-CD-CD> [0.00144928]
#     NNP -> 'Delta' [0.00245098]
#     NP -> DT NP|<JJ-X+JJ-NNS> [0.00144928]
#     NP|<JJ-X+JJ-NNS> -> JJ NP|<X+JJ-NNS> [1.0]
#     NP|<X+JJ-NNS> -> X+JJ NNS [1.0]
#     X+JJ -> 'nonstop' [1.0]
#     NNP -> 'Louis' [0.00735294]
#     IN -> 'before' [0.026971]
#     NP -> NP+DT PP [0.00289855]
#     NP+DT -> 'any' [0.0666667]
#     VP -> VB NP+NNS [0.00636943]
#     NP+NNS -> 'stops' [0.0144928]
#     SQ -> VBP SQ|<NP+DT-NP> [0.0133333]
#     VBP -> 'Are' [0.00877193]
#     SQ|<NP+DT-NP> -> NP+DT NP [1.0]
#     SQ -> VBP SQ|<NP+NP+EX-PP-PP-PP> [0.0266667]
#     SQ|<NP+NP+EX-PP-PP-PP> -> NP+NP+EX SQ|<PP-PP-PP> [1.0]
#     SQ|<PP-PP-PP> -> PP SQ|<PP-PP> [1.0]
#     NP+NNP -> 'Saturday' [0.0155211]
#     SQ -> VBP SQ|<NP+NP+EX-PP-PP> [0.173333]
#     SQ|<NP+NP+EX-PP-PP> -> NP+NP+EX SQ|<PP-PP> [1.0]
#     SQ+VP -> VBP SQ+VP|<NP+NNP-PP-PP> [0.04]
#     SQ+VP|<NP+NNP-PP-PP> -> NP+NNP SQ+VP|<PP-PP> [1.0]
#     CD -> 'nine' [0.05]
#     S+VP -> VB NP+NNS [0.0143885]
#     NP+NNS -> 'flights' [0.231884]
#     NP -> NN NP|<NNP-NNP-CD-CD-CD> [0.00144928]
#     NP|<NNP-NNP-CD-CD-CD> -> NNP NP|<NNP-CD-CD-CD> [1.0]
#     NP|<NNP-CD-CD-CD> -> NNP NP|<CD-CD-CD> [1.0]
#     NNP -> 'N' [0.00490196]
#     CD -> 'zero' [0.00714286]
#     NP+NNP -> 'Memphis' [0.0310421]
#     NP -> NP+NNS NP|<PP-PP> [0.0101449]
#     FRAG+NP -> NP+NNS FRAG+NP|<PP-PP> [0.2]
#     NP+NNS -> 'Flights' [0.594203]
#     NP+NNP -> 'Cleveland' [0.059867]
#     TOP -> FRAG+VP PUNC [0.0170576]
#     FRAG+VP -> VBG FRAG+VP|<NP+NNP-PP> [0.125]
#     VBG -> 'Leaving' [0.117647]
#     FRAG+VP|<NP+NNP-PP> -> NP+NNP PP [1.0]
#     NP+NNS -> 'costs' [0.0144928]
#     FRAG+VP -> VBG PP [0.125]
#     VBG -> 'Arriving' [0.0294118]
#     FRAG+NP+NN -> 'Cost' [0.5]
#     FRAG -> PP VP [0.0344828]
#     NP -> JJ NP|<JJ-NN> [0.00144928]
#     JJ -> 'Last' [0.030303]
#     NN -> 'night' [0.00711744]
#     FRAG+NP -> NP+NNS FRAG+NP|<PP-PP-NP> [0.00952381]
#     FRAG+NP|<PP-PP-NP> -> PP FRAG+NP|<PP-NP> [1.0]
#     FRAG+NP|<PP-NP> -> PP NP [1.0]
#     NNP -> 'Thursday' [0.0147059]
#     FRAG+NP -> NP+NNS FRAG+NP|<PP-PP-PP> [0.0380952]
#     NP+NNP -> 'Friday' [0.0199557]
#     FRAG+NP -> NP+NNS FRAG+NP|<PP-PP-PP-PP> [0.0190476]
#     FRAG+NP|<PP-PP-PP-PP> -> PP FRAG+NP|<PP-PP-PP> [1.0]
#     NNP -> 'U' [0.00980392]
#     NNP -> 'S' [0.00735294]
#     NNP -> 'Air' [0.00735294]
#     FRAG+NP -> JJS NN [0.0380952]
#     JJS -> 'Earliest' [0.03125]
#     NN -> 'nonstop' [0.00711744]
#     FRAG+NP -> NP VP+VBG [0.00952381]
#     VP+VBG -> 'returning' [1.0]
#     PP -> IN PP|<CC-IN-NP> [0.00146413]
#     PP|<CC-IN-NP> -> CC PP|<IN-NP> [1.0]
#     PP|<IN-NP> -> IN NP [1.0]
#     CD -> 'eight' [0.0285714]
#     NP -> NP NP|<CC-PP-PP> [0.00144928]
#     NP|<CC-PP-PP> -> CC NP|<PP-PP> [1.0]
#     S+VP -> VBZ ADVP+RB [0.00719424]
#     ADVP+RB -> 'first' [0.0625]
#     NP -> NP SBAR+S+VP [0.00144928]
#     JJ -> 'last' [0.0151515]
#     SBAR+S+VP -> TO VP+VB [1.0]
#     VP+VB -> 'leave' [0.166667]
#     NP -> NP+NNS PP [0.00434783]
#     NP+NNP -> 'Tennessee' [0.00221729]
#     NP -> NP+NNS NP|<VP-SBAR> [0.00144928]
#     VP -> VBG VP|<PP-PP> [0.0191083]
#     PP -> PP PP|<CC-PP> [0.00146413]
#     PP|<CC-PP> -> CC PP [1.0]
#     S+VP -> VBP ADVP [0.00719424]
#     ADVP -> NP RB [0.571429]
#     NP -> QP NNS [0.0101449]
#     QP -> RBR QP|<IN-CD> [0.285714]
#     RBR -> 'less' [1.0]
#     QP|<IN-CD> -> IN CD [1.0]
#     IN -> 'than' [0.0145228]
#     NNS -> 'minutes' [0.0239234]
#     RB -> 'apart' [0.0754717]
#     VB -> 'Give' [0.0060241]
#     NP -> NP NNS [0.00144928]
#     NNP -> 'Sunday' [0.00490196]
#     NP -> NP+NNS VP [0.00289855]
#     IN -> 'within' [0.00207469]
#     NP -> CD NP|<NNS-PP> [0.00144928]
#     NP|<NNS-PP> -> NNS PP [1.0]
#     DT -> 'each' [0.00505051]
#     S -> ADVP+RB VP [0.0327869]
#     ADVP+RB -> 'Only' [0.125]
#     NP -> NP+NNS NP|<VP-ADVP> [0.00434783]
#     NP|<VP-ADVP> -> VP ADVP [1.0]
#     NP -> NP NP|<CC-NP+NNP> [0.0057971]
#     NP|<CC-NP+NNP> -> CC NP+NNP [1.0]
#     TOP -> NP PUNC [0.00639659]
#     VP -> VBG VP|<PP-PP-PP> [0.00636943]
#     VB -> 'display' [0.0060241]
#     FRAG -> ADVP+RB NP+NNP [0.0344828]
#     ADVP+RB -> 'Anytime' [0.0625]
#     FRAG -> NP+NNP PP [0.172414]
#     NP -> NP+NNS NP|<PP-PP-NP> [0.00144928]
#     FRAG+NP -> NNP NN [0.0190476]
#     NP -> CD NP|<CD-NNS> [0.00434783]
#     CD -> 'seventeen' [0.00714286]
#     NP|<CD-NNS> -> CD NNS [1.0]
#     CD -> 'hundred' [0.0571429]
#     NNS -> 'hours' [0.0191388]
#     FRAG -> NP FRAG|<NP-PP-PP> [0.0344828]
#     FRAG|<NP-PP-PP> -> NP FRAG|<PP-PP> [1.0]
#     NNP -> 'Wednesday' [0.00980392]
#     NP -> JJ NP|<NNP-NNS> [0.00144928]
#     JJ -> 'Next' [0.0151515]
#     NP|<NNP-NNS> -> NNP NNS [1.0]
#     FRAG+NP -> NP+NNS PP [0.0666667]
#     TOP -> FRAG+NP+NNP PUNC [0.0021322]
#     FRAG+NP+NNP -> 'Tuesday' [1.0]
#     SQ+VP -> VBP SQ+VP|<PP-PP-NP> [0.02]
#     SQ+VP|<PP-PP-NP> -> PP SQ+VP|<PP-NP> [1.0]
#     SQ+VP|<PP-NP> -> PP NP [1.0]
#     FRAG -> PP PP [0.137931]
#     IN -> 'From' [0.0103734]
#     NNP -> 'Friday' [0.00735294]
#     NP -> JJ NP|<NN-NNS> [0.00724638]
#     JJ -> 'Early' [0.0151515]
#     NP -> NNP NP|<CC-NNP> [0.00289855]
#     NNP -> 'Cincinnati' [0.00245098]
#     NP|<CC-NNP> -> CC NNP [1.0]
#     NNP -> 'Tampa' [0.00245098]
#     FRAG+NP -> NN NNS [0.00952381]
#     NN -> 'Morning' [0.00355872]
#     NP -> JJS NP|<NN-NNS> [0.00144928]
#     JJS -> 'Shortest' [0.09375]
#     NP -> JJS NP|<NN-NN> [0.00144928]
#     FRAG+VP -> VBG FRAG+VP|<NP-PP> [0.25]
#     FRAG+VP|<NP-PP> -> NP PP [1.0]
#     FRAG -> PP FRAG|<PP-VP> [0.0344828]
#     FRAG|<PP-VP> -> PP VP [1.0]
#     VBG -> 'departing' [0.0882353]
#     TOP -> FRAG+WHNP PUNC [0.0703625]
#     FRAG+WHNP -> WHNP FRAG+WHNP|<PP-PP-PP> [0.393939]
#     FRAG+WHNP|<PP-PP-PP> -> PP FRAG+WHNP|<PP-PP> [1.0]
#     FRAG+WHNP|<PP-PP> -> PP PP [1.0]
#     FRAG+WHNP -> NP FRAG+WHNP|<PP-PP-PP> [0.030303]
#     NP -> WDT NNS [0.00144928]
#     CD -> 'forty' [0.0142857]
#     FRAG -> WHNP PP [0.0344828]
#     FRAG -> WHNP FRAG|<PP-PP> [0.0689655]
#     FRAG+WHNP -> WHNP FRAG+WHNP|<PP-PP> [0.393939]
#     FRAG+WHNP -> WHNP FRAG+WHNP|<PP-PP-PP-PP> [0.121212]
#     FRAG+WHNP|<PP-PP-PP-PP> -> PP FRAG+WHNP|<PP-PP-PP> [1.0]
#     FRAG+WHNP -> WHNP FRAG+WHNP|<PP-PP-PP-PP-PP> [0.030303]
#     FRAG+WHNP|<PP-PP-PP-PP-PP> -> PP FRAG+WHNP|<PP-PP-PP-PP> [1.0]
#     NN -> 'price' [0.0391459]
#     SQ+VP -> VBP NP+NNS [0.02]
#     NP+NNS -> 'meals' [0.0144928]
#     FRAG+WHNP -> WHNP PP [0.030303]
#     NNS -> 'restrictions' [0.00478469]
#     NP -> NN NP|<NN-SYM> [0.00144928]
#     NP|<NN-SYM> -> NN SYM [1.0]
#     NN -> 'code' [0.00711744]
#     SYM -> 'H' [0.166667]
#     NP -> NN NP|<NNP-NNP-CD-CD> [0.00144928]
#     NP|<NNP-NNP-CD-CD> -> NNP NP|<NNP-CD-CD> [1.0]
#     NP|<NNP-CD-CD> -> NNP NP|<CD-CD> [1.0]
#     TOP -> FRAG+PP PUNC [0.010661]
#     FRAG+PP -> IN NP+NNP [0.2]
#     NN -> 'seating' [0.00355872]
#     NN -> 'capacity' [0.00355872]
#     VBP -> "'re" [0.00877193]
#     NN -> 'kind' [0.00355872]
#     NP+NN -> 'airplane' [0.0196078]
#     SQ -> VBP SQ|<NP+PRP-VP+VB> [0.0133333]
#     SQ|<NP+PRP-VP+VB> -> NP+PRP VP+VB [1.0]
#     NP+PRP -> 'they' [0.00735294]
#     VP+VB -> 'use' [0.166667]
#     FRAG+NP -> NP+NNS FRAG+NP|<PP-PP-PP-VP> [0.00952381]
#     FRAG+NP|<PP-PP-PP-VP> -> PP FRAG+NP|<PP-PP-VP> [1.0]
#     FRAG+NP|<PP-PP-VP> -> PP FRAG+NP|<PP-VP> [1.0]
#     FRAG+NP|<PP-VP> -> PP VP [1.0]
#     FRAG+NP -> NP+NNS FRAG+NP|<PP-PP-VP> [0.00952381]
#     FRAG+NP -> NP+NN PP [0.0571429]
#     NP+NN -> 'Price' [0.137255]
#     NP -> JJ NP|<NN-NN> [0.00144928]
#     FRAG -> NP+NN FRAG|<PP-PP-NP> [0.0344828]
#     FRAG|<PP-PP-NP> -> PP FRAG|<PP-NP> [1.0]
#     FRAG|<PP-NP> -> PP NP [1.0]
#     NP -> NN NP|<NNP-NNP-CD-CD-CD-CD> [0.00289855]
#     NP|<NNP-NNP-CD-CD-CD-CD> -> NNP NP|<NNP-CD-CD-CD-CD> [1.0]
#     NP|<NNP-CD-CD-CD-CD> -> NNP NP|<CD-CD-CD-CD> [1.0]
#     NP|<CD-CD-CD-CD> -> CD NP|<CD-CD-CD> [1.0]
#     FRAG+NP -> NP FRAG+NP|<CC-NP+NN> [0.00952381]
#     FRAG+NP|<CC-NP+NN> -> CC NP+NN [1.0]
#     NP+NN -> 'price' [0.0196078]
#     FRAG+NP -> NP+NN FRAG+NP|<PP-PP> [0.0285714]
#     NP -> NN NP|<NNP-NNP-CD-CD-CD-CD-CD> [0.00144928]
#     NP|<NNP-NNP-CD-CD-CD-CD-CD> -> NNP NP|<NNP-CD-CD-CD-CD-CD> [1.0]
#     NP|<NNP-CD-CD-CD-CD-CD> -> NNP NP|<CD-CD-CD-CD-CD> [1.0]
#     NP|<CD-CD-CD-CD-CD> -> CD NP|<CD-CD-CD-CD> [1.0]
#     CD -> 'thousand' [0.00714286]
#     CD -> 'three' [0.0142857]
#     CD -> 'nineteen' [0.00714286]
#     NP -> JJS NN [0.0115942]
#     NP+NNP -> 'California' [0.00221729]
#     NP+NNP -> 'Florida' [0.00221729]
#     FRAG+NP -> NP+NN FRAG+NP|<PP-PP-SBAR> [0.00952381]
#     FRAG+NP|<PP-PP-SBAR> -> PP FRAG+NP|<PP-SBAR> [1.0]
#     FRAG+NP|<PP-SBAR> -> PP SBAR [1.0]
#     VBZ -> 'departs' [0.0172414]
#     PP -> NP PP|<IN-S+VP+VBG> [0.00146413]
#     PP|<IN-S+VP+VBG> -> IN S+VP+VBG [1.0]
#     S+VP+VBG -> 'arriving' [1.0]
#     JJ -> 'First' [0.030303]
#     NP -> JJS NP|<JJ-NN-NN> [0.00289855]
#     JJS -> 'Cheapest' [0.40625]
#     NN -> 'airfare' [0.0177936]
#     NP -> JJ NP|<NN-JJ-NN-NN> [0.00144928]
#     NP|<NN-JJ-NN-NN> -> NN NP|<JJ-NN-NN> [1.0]
#     SQ -> INTJ+UH SQ|<MD-NP+PRP-VP> [0.0133333]
#     INTJ+UH -> 'Hi' [0.0833333]
#     SQ|<MD-NP+PRP-VP> -> MD SQ|<NP+PRP-VP> [1.0]
#     MD -> 'could' [0.0384615]
#     VB -> 'get' [0.0060241]
#     NP -> DT NP|<CD-NN-NN> [0.00144928]
#     NP|<CD-NN-NN> -> CD NP|<NN-NN> [1.0]
#     NN -> 'ticket' [0.00355872]
#     NP+DT -> 'those' [0.266667]
#     SQ+VP -> VBZ NP [0.02]
#     NP -> CC NP|<NNP-CC-NNP> [0.00144928]
#     CC -> 'either' [0.0243902]
#     NP|<NNP-CC-NNP> -> NNP NP|<CC-NNP> [1.0]
#     SQ+VP -> VBP NP+NNP [0.02]
#     VB -> 'cancel' [0.0060241]
#     FRAG -> X NP+NNP [0.0344828]
#     WP -> 'what' [0.25]
#     NP+DT -> 'Any' [0.0666667]
#     SQ+VP -> VBZ ADJP+JJR [0.04]
#     ADJP+JJR -> 'better' [1.0]
#     FRAG+VP -> VBG NP [0.125]
#     VBG -> 'Traveling' [0.0294118]
#     NNP -> 'Westchester' [0.00980392]
#     NNP -> 'County' [0.00980392]
#     NNP -> 'Paul' [0.00490196]
#     NNP -> 'Newark' [0.00245098]
#     NNP -> 'Cleveland' [0.00490196]
#     NNP -> 'Ohio' [0.00490196]
#     FRAG+NP -> JJ FRAG+NP|<NN-NNS> [0.00952381]
#     JJ -> 'Round' [0.030303]
#     FRAG+NP|<NN-NNS> -> NN NNS [1.0]
#     FRAG+NP -> DT NNS [0.00952381]
#     DT -> 'No' [0.00505051]
#     FRAG+NP -> NN FRAG+NP|<NN-NNP-NNP-CD-CD-CD-CD> [0.00952381]
#     FRAG+NP|<NN-NNP-NNP-CD-CD-CD-CD> -> NN FRAG+NP|<NNP-NNP-CD-CD-CD-CD> [1.0]
#     FRAG+NP|<NNP-NNP-CD-CD-CD-CD> -> NNP FRAG+NP|<NNP-CD-CD-CD-CD> [1.0]
#     FRAG+NP|<NNP-CD-CD-CD-CD> -> NNP FRAG+NP|<CD-CD-CD-CD> [1.0]
#     NNP -> 'O' [0.00245098]
#     FRAG+NP|<CD-CD-CD-CD> -> CD FRAG+NP|<CD-CD-CD> [1.0]
#     FRAG+NP|<CD-CD-CD> -> CD FRAG+NP|<CD-CD> [1.0]
#     FRAG+NP|<CD-CD> -> CD CD [1.0]
#     FRAG+NP -> NN FRAG+NP|<NN-NN> [0.00952381]
#     NN -> 'Return' [0.00711744]
#     FRAG+NP|<NN-NN> -> NN NN [1.0]
#     DT -> 'All' [0.020202]
#     TOP -> FRAG+ADJP+JJ PUNC [0.00426439]
#     FRAG+ADJP+JJ -> 'Nonstop' [1.0]
#     FRAG+NP -> CD NNS [0.00952381]
#     CD -> 'Zero' [0.00714286]
#     FRAG+NP -> JJ NNS [0.00952381]
#     JJ -> 'Direct' [0.0151515]
#     NP -> NN NP|<NN-NNS> [0.00434783]
#     NN -> 'business' [0.00711744]
#     NNP -> 'J' [0.00980392]
#     NNP -> 'F' [0.0147059]
#     NNP -> 'K' [0.00980392]
#     NP -> NN NP|<NNP-NNP> [0.00144928]
#     FRAG+NP -> NN FRAG+NP|<NN-NNS> [0.0190476]
#     NN -> 'Business' [0.00355872]
#     FRAG+NP -> NP+NNP FRAG+NP|<PP-PP> [0.00952381]
#     NP+NNP -> 'Arrival' [0.00221729]
#     FRAG+PP -> IN NP [0.8]
#     IN -> 'With' [0.00622407]
#     NP -> DT NP|<ADJP-NN> [0.00144928]
#     NP|<ADJP-NN> -> ADJP NN [1.0]
#     ADJP -> RBS JJ [0.2]
#     RBS -> 'least' [1.0]
#     JJ -> 'expensive' [0.0151515]
#     FRAG -> NP NP [0.0689655]
#     FRAG+NP -> JJS FRAG+NP|<JJ-NN-NN> [0.0190476]
#     FRAG+NP|<JJ-NN-NN> -> JJ FRAG+NP|<NN-NN> [1.0]
#     TOP -> ADJP+JJ PUNC [0.0021322]
#     ADJP+JJ -> 'Nonstop' [0.111111]
#     FRAG+NP -> NN NN [0.0285714]
#     NN -> 'Ground' [0.0106762]
#     FRAG+NP -> NP+NNS FRAG+NP|<PP-NP> [0.00952381]
#     NNP -> 'Milwaukee' [0.00245098]
#     NNP -> 'Orlando' [0.00245098]
#     FRAG+VP -> VBG FRAG+VP|<PP-PP> [0.375]
#     FRAG+VP|<PP-PP> -> PP PP [1.0]
#     PP -> IN NP+NNPS [0.00146413]
#     NP+NNPS -> 'Wednesdays' [1.0]
#     IN -> 'After' [0.00207469]
#     JJS -> 'Lowest' [0.03125]
#     NP+NN -> 'Departure' [0.0196078]
#     NP -> NP NP [0.00289855]
#     JJS -> 'lowest' [0.03125]
#     NP -> CD NP|<NN-NNS> [0.00289855]
#     TOP -> FRAG+ADJP+JJS PUNC [0.0021322]
#     FRAG+ADJP+JJS -> 'Cheapest' [1.0]
#     VBG -> 'Departing' [0.0588235]
#     PP -> IN NP+NNS [0.00439239]
#     NP+NNS -> 'Wednesdays' [0.0144928]
#     NP -> CD NP|<RB-RB> [0.0057971]
#     NP|<RB-RB> -> RB RB [1.0]
#     RB -> "o'clock" [0.0943396]
#     NP -> NNP NNS [0.00144928]
#     NNS -> 'mornings' [0.00478469]
#     NP -> NP+NNS NP|<PP-PP-PP> [0.00144928]
#     NP+NNS -> 'weekdays' [0.0434783]
#     IN -> 'during' [0.00207469]
#     NN -> 'Weekday' [0.00355872]
#     FRAG+NP -> NP+NNS FRAG+NP|<PP-PP-NP+NNS> [0.00952381]
#     FRAG+NP|<PP-PP-NP+NNS> -> PP FRAG+NP|<PP-NP+NNS> [1.0]
#     FRAG+NP|<PP-NP+NNS> -> PP NP+NNS [1.0]
#     FRAG+NP -> NP+NNS FRAG+NP|<PP-PP-ADVP+RB-NP> [0.00952381]
#     FRAG+NP|<PP-PP-ADVP+RB-NP> -> PP FRAG+NP|<PP-ADVP+RB-NP> [1.0]
#     FRAG+NP|<PP-ADVP+RB-NP> -> PP FRAG+NP|<ADVP+RB-NP> [1.0]
#     FRAG+NP|<ADVP+RB-NP> -> ADVP+RB NP [1.0]
#     ADVP+RB -> 'daily' [0.25]
#     FRAG+NP -> NP FRAG+NP|<PP-PP-VP> [0.00952381]
#     JJ -> 'Daily' [0.0151515]
#     FRAG+NP -> NP+NNS FRAG+NP|<PP-PP-NP-ADVP+RB> [0.00952381]
#     FRAG+NP|<PP-PP-NP-ADVP+RB> -> PP FRAG+NP|<PP-NP-ADVP+RB> [1.0]
#     FRAG+NP|<PP-NP-ADVP+RB> -> PP FRAG+NP|<NP-ADVP+RB> [1.0]
#     FRAG+NP|<NP-ADVP+RB> -> NP ADVP+RB [1.0]
#     FRAG -> NP+NNP FRAG|<PP-ADVP+RB> [0.0344828]
#     FRAG|<PP-ADVP+RB> -> PP ADVP+RB [1.0]
#     FRAG+NP -> NP+NNS FRAG+NP|<PP-PP-ADVP+RB> [0.00952381]
#     FRAG+NP|<PP-PP-ADVP+RB> -> PP FRAG+NP|<PP-ADVP+RB> [1.0]
#     FRAG+NP|<PP-ADVP+RB> -> PP ADVP+RB [1.0]
#     NP+NNS -> 'Airports' [0.0289855]
#     NNP -> 'La' [0.00735294]
#     NNP -> 'Guardia' [0.00735294]
#     NN -> 'Coach' [0.0106762]
#     S -> NP+NN VP [0.0163934]
#     VP -> VBZ NP [0.00636943]
#     FRAG+NP -> NP FRAG+NP|<PP-ADJP> [0.00952381]
#     FRAG+NP|<PP-ADJP> -> PP ADJP [1.0]
#     ADJP -> JJR PP [0.4]
#     JJR -> 'less' [0.75]
#     QP -> CD QP|<CD-CD> [0.142857]
#     QP|<CD-CD> -> CD CD [1.0]
#     NNS -> 'dollars' [0.0191388]
#     NP+NNS -> 'Fares' [0.0289855]
#     NP -> QP NP|<NNS-QP> [0.00144928]
#     NP|<NNS-QP> -> NNS QP [1.0]
#     QP -> CC JJR [0.0714286]
#     FRAG+NP -> NP+NNS ADJP [0.00952381]
#     QP -> CD QP|<CD-CD-CD> [0.0714286]
#     QP|<CD-CD-CD> -> CD QP|<CD-CD> [1.0]
#     NP+NNS -> 'fares' [0.0144928]
#     QP -> RB QP|<JJR-IN-CD-CD-CD> [0.0714286]
#     RB -> 'no' [0.0188679]
#     QP|<JJR-IN-CD-CD-CD> -> JJR QP|<IN-CD-CD-CD> [1.0]
#     JJR -> 'more' [0.25]
#     QP|<IN-CD-CD-CD> -> IN QP|<CD-CD-CD> [1.0]
#     FRAG+NP -> JJS NNS [0.00952381]
#     NP -> DT NP|<JJS-NNS> [0.00144928]
#     NP|<JJS-NNS> -> JJS NNS [1.0]
#     JJS -> 'cheapest' [0.09375]
#     S+VP -> VP S+VP|<CC-VP> [0.0143885]
#     S+VP|<CC-VP> -> CC VP [1.0]
#     NP -> DT NP|<JJS-JJ-NN-NNS> [0.00144928]
#     NP|<JJS-JJ-NN-NNS> -> JJS NP|<JJ-NN-NNS> [1.0]
#     NP -> DT NP|<JJ-NNS> [0.00144928]
#     NP|<JJ-NNS> -> JJ NNS [1.0]
#     TOP -> X+S+VP PUNC [0.0021322]
#     X+S+VP -> VB X+S+VP|<NP+PRP-NP> [1.0]
#     X+S+VP|<NP+PRP-NP> -> NP+PRP NP [1.0]
#     PP -> TO INTJ+UH [0.00146413]
#     INTJ+UH -> 'oh' [0.0833333]
#     INTJ+UH -> 'oops' [0.0833333]
#     NNP -> 'Southwest' [0.00980392]
#     NP -> DT NP|<NNP-NNP-NNS> [0.00289855]
#     NP|<NNP-NNP-NNS> -> NNP NP|<NNP-NNS> [1.0]
#     NP -> RB NP|<DT-NNP-NNP-NNS> [0.00144928]
#     RB -> 'only' [0.0188679]
#     NP|<DT-NNP-NNP-NNS> -> DT NP|<NNP-NNP-NNS> [1.0]
#     S+VP -> VBP S+VP|<RB-VP> [0.00719424]
#     S+VP|<RB-VP> -> RB VP [1.0]
#     RB -> 'not' [0.0188679]
#     NP -> DT NP|<NNP-NNP-NNP-NNS> [0.00144928]
#     NP|<NNP-NNP-NNP-NNS> -> NNP NP|<NNP-NNP-NNS> [1.0]
#     NP -> DT NP|<NNP-NNP-NN> [0.00144928]
#     NP|<NNP-NNP-NN> -> NNP NP|<NNP-NN> [1.0]
#     IN -> 'into' [0.00207469]
#     NP+NNP -> 'Dulles' [0.00221729]
#     NNP -> 'Dulles' [0.00245098]
#     S+VP -> VBZ NP+NN [0.00719424]
#     VBZ -> 'has' [0.0172414]
#     NN -> 'meal' [0.00355872]
#     VB -> 'Explain' [0.0180723]
#     NNS -> 'codes' [0.00956938]
#     NP -> DT NP|<NN-SYM-SYM-SYM-CD-CD> [0.00144928]
#     NP|<NN-SYM-SYM-SYM-CD-CD> -> NN NP|<SYM-SYM-SYM-CD-CD> [1.0]
#     NN -> 'restriction' [0.00355872]
#     NP|<SYM-SYM-SYM-CD-CD> -> SYM NP|<SYM-SYM-CD-CD> [1.0]
#     SYM -> 'A' [0.166667]
#     NP|<SYM-SYM-CD-CD> -> SYM NP|<SYM-CD-CD> [1.0]
#     SYM -> 'P' [0.166667]
#     NP|<SYM-CD-CD> -> SYM NP|<CD-CD> [1.0]
#     SYM -> 'slash' [0.166667]
#     NP -> DT NP|<NN-NN-SYM> [0.00144928]
#     NP|<NN-NN-SYM> -> NN NP|<NN-SYM> [1.0]
#     SYM -> 'Q' [0.166667]
#     VBP -> 'accept' [0.00877193]
#     JJ -> 'frequent' [0.0151515]
#     NN -> 'flyer' [0.00355872]
#     NNS -> 'tickets' [0.00478469]
#     VB -> 'Display' [0.0060241]

# %% [markdown]
# ## Part 5: Probabilistic CKY parsing
#
# Finally, we are ready to implement probabilistic CKY parsing under PCFGs. Adapt the CKY parser from Part 3 to return the most likely parse and its **log probability** (base 2) given a PCFG. Note that to avoid underflows we want to work in the log space.
# > **Hint:** `production.logprob()` will return the log probability of a production rule `production`.

# %%
## TODO – Implement a CKY parser under PCFGs
def cky_parse_probabilistic(grammar, tokens):
# """Returns the NLTK parse tree of `tokens` with the highest probability 
# as specified by the PCFG `grammar` and its log probability as a tuple.

# Returns (None, -float('inf')) if `tokens` is not parsable.
# Implements the CKY algorithm, and therefore assumes `grammar` is in 
# Chomsky normal form.
# """
    assert(grammar.is_chomsky_normal_form())
    
    T = [[defaultdict() for i in range(len(tokens)+1)] for j in range(len(tokens)+1)]
    back = [[defaultdict() for i in range(len(tokens)+1)] for j in range(len(tokens)+1)]
    
    for j in range(1, len(tokens)+1):
        for prod in grammar.productions():
            
            if(prod.rhs()[0] == tokens[j-1]): 
                T[j-1][j][prod.lhs()] = prod.logprob()
                
        for length in range(2,j+1):
            i = j-length
            for split in range(i+1, j):
                for prod in grammar.productions():
                    if (prod.rhs()[0] in T[i][split] and T[i][split][prod.rhs()[0]] != -float('inf') and
                    prod.rhs()[1] in T[split][j] and T[split][j][prod.rhs()[1]] != -float('inf')):
                        new_prob = prod.logprob() + T[i][split][prod.rhs()[0]] + T[split][j][prod.rhs()[1]]
                        if(prod.lhs() in T[i][j] and new_prob > T[i][j][prod.lhs()]):
                            T[i][j][prod.lhs()] = new_prob
                            back[i][j][prod.lhs()] = (split, prod.rhs()[0], prod.rhs()[1])
                        if(not(prod.lhs() in T[i][j])):
                            T[i][j][prod.lhs()] = new_prob
                            back[i][j][prod.lhs()] = (split, prod.rhs()[0], prod.rhs()[1])
                            
    
    if (not (grammar.start() in T[0][len(tokens)])):
        return (None, -float('inf'))
    
    parse = rec2(0, len(tokens), tokens, T, back, grammar.start())
    return (Tree.fromstring(parse), T[0][len(tokens)][grammar.start()])

# %%
def rec2(start, end, tokens, T, back, k):
    if(start == end-1): return f'({k} {tokens[start]})'
    triplette = back[start][end][k]
    leftparse = rec2(start, triplette[0], tokens, T, back, triplette[1])
    rightparse = rec2(triplette[0], end, tokens, T, back, triplette[2])
    return f'({k} {leftparse} {rightparse})'

# %% [markdown]
# As an aid in debugging, you may want to start by testing your implementation of probabilistic CKY on a much smaller grammar than the one you trained from the ATIS corpus. Here's a little grammar that you can play with.
#
# > **Hint:** By "play with", we mean that you can change the gramamr to try out the behavior of your parser on different test grammars, including ambiguous cases.

# %%
grammar = PCFG.fromstring("""
  S -> NP VP [1.0]
  VP -> V NP [1.0]
  PP -> P NP [1.0]
  NP -> 'sam' [.3]
  NP -> 'ham' [.7]
  V -> 'likes' [1.0]
  """)

# %%
tree, logprob = cky_parse_probabilistic(grammar, tokenize('sam likes ham'))
tree.pretty_print()
print(f"logprob: {logprob:4.3g} | probability: {2**logprob:4.3g}")
# Out:
#       S
#   ____|____
#  |         VP
#  |     ____|___
#  NP   V        NP
#  |    |        |
# sam likes     ham
#
# logprob: -2.25 | probability: 0.21

# %%
# We don't use our tokenizer because the gold trees do not lowercase tokens
sent = "Flights from Cleveland to Kansas City .".split()
tree, logprob = cky_parse_probabilistic(pgrammar, sent)
tree.un_chomsky_normal_form()
tree.pretty_print()
print(f"logprob: {logprob:4.3g} | probability: {2**logprob:4.3g}")
# Out:
#                            TOP
#                       ______|___________________
#                     FRAG                        |
#                      |                          |
#                      NP                         |
#     _________________|___________               |
#    |          PP                 PP             |
#    |      ____|______        ____|_____         |
#    NP    |           NP     |          NP       |
#    |     |           |      |     _____|___     |
#   NNS    IN         NNP     TO  NNP       NNP  PUNC
#    |     |           |      |    |         |    |
# Flights from     Cleveland  to Kansas     City  .
#
# logprob:  -27 | probability: 7.42e-09

# %% [markdown]
# ## Evaluation of the grammar
#
# There are a number of ways to evaluate parsing algorithms. In this project segment, you will use the ["industry-standard" `evalb` implementation](https://nlp.cs.nyu.edu/evalb/) for computing constituent precision, recall, and F1 scores. We downloaded `evalb` during setup.
#
# We read in the test data...

# %%
with open('data/test.trees') as file:
  test_trees = [Tree.fromstring(line.strip()) for line in file.readlines()]

test_sents = [tree.leaves() for tree in test_trees]

# %% [markdown]
# ...and parse the test sentences using your probabilistic CKY implementation, writing the output trees to a file.

# %%
trees_out = []
for sent in tqdm(test_sents):
  tree, prob = cky_parse_probabilistic(pgrammar, sent)
  if tree is not None:
    tree.un_chomsky_normal_form()
    trees_out.append(tree.pformat(margin=9999999999))
  else:
    trees_out.append('()')
  
with open('data/outp.trees', 'w') as file:
  for line in trees_out:
    file.write(line + '\n')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 58/58 [00:14<00:00,  3.91it/s]

# %% [markdown]
# Now we can compare the predicted trees to the ground truth trees, using `evalb`. You should expect to achieve F1 of about 0.83.

# %%
shell("python scripts/evalb.py data/outp.trees data/test.trees")
# Out:
# data/outp.trees	345 brackets
# data/test.trees	471 brackets
# matching	339 brackets
# precision	0.9826086956521739
# recall	0.7197452229299363
# F1	0.8308823529411764

# %% [markdown]
# ## Debrief
#
# **Question:** We're interested in any thoughts you have about this project segment so that we can improve it for later years, and to inform later segments for this year. Please list any issues that arose or comments you have to improve the project segment. Useful things to comment on might include the following:
#
# * Was the project segment clear or unclear? Which portions?
# * Were the readings appropriate background for the project segment?
# * Are there additions or changes you think would make the project segment better?
#     ```
#     BEGIN QUESTION
#     name: open_response_debrief
#     manual: true
#     ```
#
# but you should comment on whatever aspects you found especially positive or negative.

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# # Instructions for submission of the project segment
#
# This project segment should be submitted to Gradescope at <https://rebrand.ly/project3-submit-code> and <https://rebrand.ly/project3-submit-pdf>, which will be made available some time before the due date.
#
# Project segment notebooks are manually graded, not autograded using otter as labs are. (Otter is used within project segment notebooks to synchronize distribution and solution code however.) **We will not run your notebook before grading it.** Instead, we ask that you submit the already freshly run notebook. The best method is to "restart kernel and run all cells", allowing time for all cells to be run to completion. You should submit your code to Gradescope at the code submission assignment at <https://rebrand.ly/project3-submit-code>. Make sure that you are also submitting your `data/grammar` file as part of your solution code as well.
#
# We also request that you **submit a PDF of the freshly run notebook**. The simplest method is to use "Export notebook to PDF", which will render the notebook to PDF via LaTeX. If that doesn't work, the method that seems to be most reliable is to export the notebook as HTML (if you are using Jupyter Notebook, you can do so using `File -> Print Preview`), open the HTML in a browser, and print it to a file. Then make sure to add the file to your git commit. Please name the file the same name as this notebook, but with a `.pdf` extension. (Conveniently, the methods just described will use that name by default.) You can then perform a git commit and push and submit the commit to Gradescope at <https://rebrand.ly/project3-submit-pdf>.

# %% [markdown]
# # End of project segment 3
